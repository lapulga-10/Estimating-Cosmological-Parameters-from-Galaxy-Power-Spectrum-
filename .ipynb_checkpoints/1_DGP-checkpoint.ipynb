# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower

import seaborn as sns

print('Using CAMB %s installed at %s' % (camb.__version__, os.path.dirname(camb.__file__)))
# make sure the version and path is what you expect
# Out:
# Using CAMB 1.6.1 installed at C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\camb

# %% [markdown]
# ### $y_{obs} \sim P(y|\theta^*)$, True Data Generating Process with noise
#
# $$
# \epsilon(k) \sim \mathcal{N}\left(0, \left[\text{noise\_level} \cdot P(k)\right]^2 \right)
# $$
#
#
# $$
# P_{\text{noisy}}(k) = P(k) + \epsilon(k)
# $$

# %%
def generate_PK(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
    Generate noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-3 to ~3.16
        noise_level (float): relative Gaussian noise (e.g., 0.05 = 5%)

    Returns:
        noisy_P_k (np.array): noisy matter power spectrum at redshift z=0
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 0.5, 1024)


    ## To calculate the physical densities from the densities 
    # Baryon density
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    noise = rng.normal(0, noise_level * P_k)
    P_k_noisy = P_k + noise

    return {
        'k': k_vals,
        'P_k_noisy': P_k_noisy,
        'P_k_clean': P_k  # optional, useful for comparison
    }

# %% [markdown]
# $\theta^*$, True parameter from Planck 2018

# %%
# Define the true cosmological parameters
theta_star = {
    'H0': 67.4,
    'Omega_m': 0.315,
    'n_s': 0.965
}

# %%
# Generate the noisy power spectrum using theta_star
Pk_obs = generate_PK(
    H0=theta_star['H0'],
    Omega_m=theta_star['Omega_m'],
    n_s=theta_star['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    seed=42            # Optional, for reproducibility
)

# %%
print(len(Pk_test))
# Out:
# 1

# %%
print(Pk_test['P_k_noisy'].shape)
# Out:
# (1024,)

# %% [markdown]
# ### P(k) vs k_vals

# %%
## Ploting the P_obs vs k_vals
plt.loglog(Pk_obs['k'], Pk_obs['P_k_clean'], label='Clean')
plt.loglog(Pk_obs['k'], Pk_obs['P_k_noisy'], label='Noisy', alpha=0.6)
plt.xlabel('k [1/Mpc]')
plt.ylabel('P(k)')
plt.legend()
plt.show()

# %% [markdown]
# ### $f(P\_k))$, Density of Power Spectrum

# %%
# Extract the noisy P(k) values
P_k_noisy = Pk_obs['P_k_noisy']

# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(P_k_noisy, bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ### $(\theta^{(s)}) \sim P(\theta)$, Sample from the Prior

# %%
def prior(seed=None):
    rng = np.random.default_rng(seed)

    H0 = rng.uniform(50, 90)
    Omega_m = rng.uniform(0.2, 0.4)
    n_s = rng.uniform(0.9, 1.0)

    return {
        'H0': H0,
        'Omega_m': Omega_m,
        'n_s': n_s
    }

# %%
prior()
# Out:
# {'H0': 76.70445823843599,
#  'Omega_m': 0.29214628731699344,
#  'n_s': 0.9018037591098335}

# %% [markdown]
# ### $(y^{(s)}) \sim P(y | \theta)$, Sample from the Likelihood
# The same function but with just one output of length of k_vals

# %%
def likelihood(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
        Same function as generate_PK(), the only difference is the single output "P_K_noisy".
        Redefinng, just make it Likelihood.
        Also, note that n = len(k_vals) = 128
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 0.5, 128) 


    ## To calculate the physical densities from the densities 
    
    # Baryon density (Well Know Constant from Plank 2018)
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    noise = rng.normal(0, noise_level * P_k)
    P_k_noisy = P_k + noise
    P_k_noisy = P_k_noisy.reshape(-1, 1)

    return {'P_k_noisy': P_k_noisy}

# %% [markdown]
# # Testing Prior and Likelihood

# %%
theta_test = prior()
print(theta_test)
# Out:
# {'H0': 81.35507852271965, 'Omega_m': 0.3038759858867524, 'n_s': 0.9521499525679155}

# %%
# Generate the noisy power spectrum using theta_star
Pk_test = likelihood(
    H0=theta_test['H0'],
    Omega_m=theta_test['Omega_m'],
    n_s=theta_test['n_s'],
    noise_level=0.2   # 20% relative Gaussian noise
)

# %%
Pk_test['P_k_noisy'].shape
# Out:
# (128, 1)

# %%
# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(Pk_test['P_k_noisy'].flatten(), bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# # Bayes Flow Workflow

# %%
import bayesflow as bf

# %% [markdown]
# # $(\theta^{(s)}, y^{(s)}) \sim P(\theta, y)$,  Sample from the Joint Distribution

# %% [markdown]
# ### Simulator

# %%
simulator = bf.make_simulator([prior, likelihood])

# %%
# simulator.sample(2)

# %% [markdown]
# ###  Adapter

# %%
adapter = (
    bf.Adapter()
    .concatenate(["H0", "Omega_m", "n_s"], into="inference_variables")
    .rename("P_k_noisy", "summary_variables")
)

# %%
# adapter(dataset)

# %% [markdown]
# ### Summary Network

# %%
summary_network = bf.networks.DeepSet()

# %% [markdown]
# ### Inference Network

# %%
inference_network = bf.networks.CouplingFlow() # affine

# %% [markdown]
# ### Approximator

# %% [markdown]
# approximator = bf.approximators.ContinuousApproximator(
#  inference_network=inference_network,
#  summary_network=summary_network
#  adapter=adapter
#  )

# %%
workflow = bf.BasicWorkflow(
     inference_network=inference_network,
     summary_network=summary_network,
     adapter=adapter,
     simulator=simulator
)

# %%
#training_data = workflow.simulate(10000)
#validation_data = workflow.simulate(1000)

# %%
# history = workflow.fit_online(epochs=3, num_batches_per_epoch= 5, batch_size=64, validation_data=10)

# %%
training_data['P_k_noisy'].shape
# Out:
# (10000, 128, 1)

# %%
all_pks = training_data['P_k_noisy'].reshape(-1)
example_pk = training_data['P_k_noisy'][5000].flatten()  # shape: (128,)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(all_pks, bins=100, kde=True, stat='density', color='skyblue', edgecolor='black')

plt.title('Density of All Simulated Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(example_pk, bins=30, kde=True, stat='density', color='salmon', edgecolor='black')

plt.title('Density of $P(k)$ for a Single Simulated Observation')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# This means the simulator is correct.

# %%
# Affine Couplingflow
history = workflow.fit_offline(
    data = training_data,
    epochs=100,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - loss: 4.2592 - val_loss: 4.2337
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - loss: 4.2586 - val_loss: 4.2350
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 214ms/step - loss: 4.2638 - val_loss: 4.2352
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - loss: 4.2605 - val_loss: 4.2349
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2591 - val_loss: 4.2367
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - loss: 4.2561 - val_loss: 4.2351
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2596 - val_loss: 4.2347
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - loss: 4.2598 - val_loss: 4.2336
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2587 - val_loss: 4.2335
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2595 - val_loss: 4.2324
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - loss: 4.2582 - val_loss: 4.2330
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2591 - val_loss: 4.2323
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2570 - val_loss: 4.2317
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 211ms/step
100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 253ms/step - loss: 4.2576 - val_loss: 4.2318

# %% [markdown]
# history = workflow.fit_offline(
#     data=training_data,
#     epochs=10,
#     batch_size=64,
#     validation_data = validation_data
# )

# %%
f = bf.diagnostics.plots.loss(history)

# %% [markdown]
# # Test Data

# %%
# Set the number of posterior draws you want to get
num_datasets = 300
num_samples = 1000

# Simulate 300 scenarios
test_data = workflow.simulate(num_datasets)

# Obtain num_samples posterior samples per scenario
samples = workflow.sample(conditions=test_data, num_samples=num_samples)

# %%
f = bf.diagnostics.plots.calibration_histogram(samples, test_data)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %%
f = bf.diagnostics.plots.calibration_ecdf(samples, test_data, difference=True)

# %%
f = bf.diagnostics.plots.recovery(samples, test_data)

# %%
figures = workflow.plot_default_diagnostics(
    test_data=300,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# # Inference with Spline coupling

# %%
inference_network_spline = bf.networks.CouplingFlow(transform="spline")

# %%
workflow_spline = bf.BasicWorkflow(
     inference_network=inference_network_spline,
     summary_network=summary_network,
     adapter=adapter,
     simulator=simulator
)

# %%
history_spline = workflow_spline.fit_offline(
    data = training_data,
    epochs=100,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 102s 351ms/step - loss: 4.0544 - val_loss: 3.8743
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 250ms/step - loss: 3.8531 - val_loss: 3.8285
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 3.8291 - val_loss: 3.8420
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 278ms/step - loss: 3.8361 - val_loss: 3.8615
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 3.8107 - val_loss: 3.8004
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 3.8093 - val_loss: 3.8286
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 291ms/step - loss: 3.7985 - val_loss: 3.8053
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 25s 323ms/step - loss: 3.7890 - val_loss: 3.7929
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 278ms/step - loss: 3.7899 - val_loss: 3.7792
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 260ms/step - loss: 3.7841 - val_loss: 3.7867
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 3.7801 - val_loss: 3.8081
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 261ms/step - loss: 3.7738 - val_loss: 3.7661
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 261ms/step - loss: 3.7641 - val_loss: 3.7935
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 3.7647 - val_loss: 3.7704
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 261ms/step - loss: 3.7673 - val_loss: 3.7576
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 276ms/step - loss: 3.7593 - val_loss: 3.7595
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step - loss: 3.7669 - val_loss: 3.7821
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - loss: 3.7605 - val_loss: 3.7667
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 259ms/step - loss: 3.7652 - val_loss: 3.7740
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 3.7625 - val_loss: 3.7639
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 274ms/step - loss: 3.7622 - val_loss: 3.7611
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 295ms/step - loss: 3.7674 - val_loss: 3.8050
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 24s 302ms/step - loss: 3.7583 - val_loss: 3.7661
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 3.7619 - val_loss: 3.7617
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 3.7564 - val_loss: 3.7625
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step
100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 3.7371 - val_loss: 3.7447
# Epoch 70/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 3.7400 - val_loss: 3.7556
# Epoch 71/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7334 - val_loss: 3.7520
# Epoch 72/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 3.7353 - val_loss: 3.7478
# Epoch 73/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - loss: 3.7327 - val_loss: 3.7440
# Epoch 74/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - loss: 3.7303 - val_loss: 3.7410
# Epoch 75/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 3.7333 - val_loss: 3.7412
# Epoch 76/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 272ms/step - loss: 3.7312 - val_loss: 3.7410
# Epoch 77/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 3.7243 - val_loss: 3.7412
# Epoch 78/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 3.7275 - val_loss: 3.7395
# Epoch 79/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7254 - val_loss: 3.7431
# Epoch 80/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - loss: 3.7238 - val_loss: 3.7438
# Epoch 81/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 3.7247 - val_loss: 3.7434
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 3.7250 - val_loss: 3.7385
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7232 - val_loss: 3.7406
# Epoch 84/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 3.7213 - val_loss: 3.7385
# Epoch 85/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 3.7204 - val_loss: 3.7418
# Epoch 86/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 3.7189 - val_loss: 3.7366
# Epoch 87/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 3.7194 - val_loss: 3.7390
# Epoch 88/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 3.7176 - val_loss: 3.7414
# Epoch 89/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7191 - val_loss: 3.7396
# Epoch 90/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 3.7163 - val_loss: 3.7369
# Epoch 91/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 3.7160 - val_loss: 3.7361
# Epoch 92/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 3.7146 - val_loss: 3.7385
# Epoch 93/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 277ms/step - loss: 3.7140 - val_loss: 3.7386
# Epoch 94/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 274ms/step - loss: 3.7138 - val_loss: 3.7370
# Epoch 95/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 272ms/step - loss: 3.7125 - val_loss: 3.7380
# Epoch 96/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 3.7123 - val_loss: 3.7375
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7124 - val_loss: 3.7370
# Epoch 98/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - loss: 3.7126 - val_loss: 3.7371
# Epoch 99/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - loss: 3.7135 - val_loss: 3.7372
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 279ms/step - loss: 3.7128 - val_loss: 3.7372

# %%
f = bf.diagnostics.plots.loss(history_spline)

# %%
# test_data_spline = workflow_spline.simulate(num_datasets)
# test_data_spline = workflow_spline.simulate(num_datasets)

# %%
samples_spline = workflow_spline.sample(conditions = test_data, num_samples=num_samples)

# %%
# f = bf.diagnostics.plots.calibration_histogram(samples, test_data)
f_spline = bf.diagnostics.plots.calibration_histogram(samples_spline, test_data)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %%
figures_spline = workflow_spline.plot_default_diagnostics(
    test_data=test_data,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)
