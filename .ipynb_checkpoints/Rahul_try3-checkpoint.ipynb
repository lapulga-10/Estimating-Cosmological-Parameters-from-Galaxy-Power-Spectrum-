# %% [markdown]
# # Imports

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower
import bayesflow as bf

import seaborn as sns
import time

print('Using CAMB %s installed at %s' % (camb.__version__, os.path.dirname(camb.__file__)))
# make sure the version and path is what you expect
# Out:
# Using CAMB 1.6.1 installed at C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\camb

# %% [markdown]
# # Data generating process

# %% [markdown]
# ## Definitions

# %%
def generate_logPK(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
    Generate noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-3 to ~3.16
        noise_level (float): relative Gaussian noise (e.g., 0.05 = 5%)

    Returns:
        noisy_P_k (np.array): noisy matter power spectrum at redshift z=0
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 1, 1024)


    ## To calculate the physical densities from the densities 
    # Baryon density
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    # noise = rng.normal(0, noise_level * P_k)
    # P_k_noisy = P_k + noise

    # Step 2: Apply log10 to each output
    log_k = np.log10(k_vals)
    #log_P_k_noisy = np.log10(P_k_noisy)
    
    
    
    
    log_P_k_clean = np.log10(P_k)

    log_noise = rng.normal(0, noise_level, len(P_k))
    log_P_k_noisy = log_P_k_clean + log_noise
    
    # shape adjustments
    log_k = log_k.reshape(-1, 1)
    log_P_k_clean = log_P_k_clean.reshape(-1, 1)
    log_P_k_noisy = log_P_k_noisy.reshape(-1, 1)

    return {     
        'log_k': log_k,
        'log_P_k_noisy': log_P_k_noisy,
        'log_P_k_clean': log_P_k_clean  
    }

# %% [markdown]
# ## Generating noisy observations
#
# $\theta^*$, True parameter from Planck 2018

# %%
# Define the true cosmological parameters
theta_star = {
    'H0': 67.4,
    'Omega_m': 0.315,
    'n_s': 0.965
}

# %%
# Generate the noisy power spectrum using theta_star
Log_Pk_obs = generate_logPK(
    H0=theta_star['H0'],
    Omega_m=theta_star['Omega_m'],
    n_s=theta_star['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    seed=42            # Optional, for reproducibility
)

# %% [markdown]
# ## Visualization
#
# P(k) vs k_vals

# %%
plt.plot(Log_Pk_obs['log_k'], Log_Pk_obs['log_P_k_clean'], label='Clean')
plt.plot(Log_Pk_obs['log_k'], Log_Pk_obs['log_P_k_noisy'], label='Noisy', alpha=0.6)
plt.xlabel(r'$\log_{10}(k)\ [h/\mathrm{Mpc}]$')
plt.ylabel(r'$\log_{10}(P(k))\ [(\mathrm{Mpc}/h)^3]$')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# $f(P\_k))$, probability density of power spectrum

# %%
# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(Log_Pk_obs['log_P_k_noisy'], bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $\log_{10} P(k)$ Values')
plt.xlabel(r'$\log_{10} P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Definitions part 2
#
# Sample from prior: $(\theta^{(s)}) \sim P(\theta)$

# %%
def prior(seed=None):
    rng = np.random.default_rng(seed)

    H0 = rng.uniform(50, 90)
    Omega_m = rng.uniform(0.2, 0.4)
    n_s = rng.uniform(0.85, 1.05)

    return {
        'H0': H0,
        'Omega_m': Omega_m,
        'n_s': n_s
    }

# %% [markdown]
# Sample from the Likelihood: $(y^{(s)}) \sim P(y | \theta)$
# The same function but with just one output of length of k_vals

# %%
def likelihood(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None, n = 256):
    """
    Generate log10 of the noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-4 to 10
        noise_level (float): standard deviation of additive Gaussian noise in log space
        seed (int or None): for reproducibility

    Returns:
        log_P_k_noisy (np.array): noisy log10 power spectrum at z = 0
    """

    if k_vals is None:
        k_vals = np.logspace(-4, 1, n)

    Omega_b = 0.05
    Omega_c = Omega_m - Omega_b
    h = H0 / 100
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2

    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

    if seed is not None:
        rng = np.random.default_rng(seed)
    else:
        rng = np.random.default_rng()

    log_k = np.log10(k_vals)
    log_P_k_clean = np.log10(P_k)
    log_noise = rng.normal(0, noise_level, len(P_k))
    log_P_k_noisy = log_P_k_clean + log_noise


    # shape adjustments
    log_k = log_k.reshape(-1, 1)
    log_P_k_clean = log_P_k_clean.reshape(-1, 1)
    log_P_k_noisy = log_P_k_noisy.reshape(-1, 1)

    return {
        'log_P_k_noisy': log_P_k_noisy
    }

# %% [markdown]
# ### Testing Prior and Likelihood

# %%
theta_test = prior()
print(theta_test)
# Out:
# {'H0': 85.24251549601203, 'Omega_m': 0.3625317959852356, 'n_s': 1.0281838478397451}

# %%
# Generate the noisy power spectrum using theta_star
Log_Pk_test = likelihood(
    H0=theta_test['H0'],
    Omega_m=theta_test['Omega_m'],
    n_s=theta_test['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    n = 512
)

# %%
Log_Pk_test.keys()
# Out:
# dict_keys(['log_P_k_noisy'])

# %%
Log_Pk_test['log_P_k_noisy'].shape
# Out:
# (512, 1)

# %%
# Plot histogram and KDE for log10(P(k))
plt.figure(figsize=(8, 5))
sns.histplot(Log_Pk_test['log_P_k_noisy'].flatten(), bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $\log_{10} P(k)$ Values')
plt.xlabel(r'$\log_{10} P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bayes Flow Workflow

# %% [markdown]
# ## Sample from the Joint Distribution $(\theta^{(s)}, y^{(s)}) \sim P(\theta, y)$

# %% [markdown]
# ### Simulator

# %%
simulator = bf.make_simulator([prior, likelihood])

# %%
# simulator.sample(2)

# %% [markdown]
# ###  Adapter

# %%
adapter = (
    bf.Adapter()
    .concatenate(["H0", "Omega_m", "n_s"], into="inference_variables")
    .rename("log_P_k_noisy", "summary_variables")
)

# %%
adapter_std = (
    bf.Adapter()
    .concatenate(["H0", "Omega_m", "n_s"], into="inference_variables")
    .rename("log_P_k_noisy", "summary_variables")
    .standardize("summary_variables")
)

# %% [markdown]
# ### Summary Network

# %%
summary_network_Deep = bf.networks.DeepSet()

# %%
summary_network_MLP = bf.networks.MLP()

# %% [markdown]
# # 1) Affine Coupling Model

# %% [markdown]
# ### Affine Inference Network

# %%
inference_network_affine = bf.networks.CouplingFlow()

# %% [markdown]
# ### Affine Workflow

# %%
workflow_affine = bf.BasicWorkflow(
     inference_network=inference_network_affine,
     summary_network=summary_network_Deep,
     adapter=adapter_std,
     simulator=simulator
)

# %%
workflow_affine_MLP = bf.BasicWorkflow(
     inference_network=inference_network_affine,
     summary_network=summary_network_MLP,
     adapter=adapter_std,
     simulator=simulator
)

# %% [markdown]
# ### Simulating Datasets for
# 1) Training
# 2) Validation
# 3) Test

# %% [markdown]
# # Timing training data sampling
# start_time = time.time()
# training_data = workflow_affine.simulate(100)
# training_duration = time.time() - start_time
# print(f"Training data simulation took {training_duration:.2f} seconds.")

# %% [markdown]
# # Timing validation data sampling
# start_time = time.time()
# validation_data = workflow_affine.simulate(10)
# validation_duration = time.time() - start_time
# print(f"Validation data simulation took {validation_duration:.2f} seconds.")

# %% [markdown]
# # Timing test data sampling
# start_time = time.time()
# test_data = workflow_affine.simulate(10)
# test_duration = time.time() - start_time
# print(f"Test data simulation took {test_duration:.2f} seconds.")

# %% [markdown]
# ## Just testing

# %% [markdown]
# Plotting any random simulated dataset just to know whether the simulator working properly

# %%
training_data['log_P_k_noisy'].shape
# Out:
# (100, 256)

# %%
train_MLP = training_data

# %%
train_MLP['log_P_k_noisy'].shape
# Out:
# (100, 256)

# %%
# Out:
# (1,)

# %%
validation_data['log_P_k_noisy'].shape
# Out:
# (10, 256, 1)

# %%
val_MLP = validation_data

# %%
val_MLP['log_P_k_noisy'] = np.squeeze(val_MLP['log_P_k_noisy'], axis=-1)  # shape: (100, 256)

# %%
val_MLP['log_P_k_noisy'].shape
# Out:
# (10, 256)

# %%
training_data.keys()
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %% [markdown]
# # Training affine

# %%
#x['log_P_k_noisy'].shape
# Out:
# (100, 256)

# %%
#training_data['log_P_k_noisy'] = training_data['log_P_k_noisy'][:, :, np.newaxis]

# %%
#training_data['log_P_k_noisy'].shape
# --> (100, 256, 1)
# Out:
# (100, 256, 1, 1)

# %%
#validation_data['log_P_k_noisy'] = validation_data['log_P_k_noisy'][:, :, np.newaxis]

# %%
#validation_data['log_P_k_noisy'].shape
# Out:
# (10, 256, 1)

# %%
#val_MLP['log_P_k_noisy'].shape
# Out:
# (100, 256)

# %%
#val_MLP['log_P_k_noisy'] = train_MLP['log_P_k_noisy'].reshape(100, 256)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
history_affine = workflow_affine.fit_offline(
    data = training_data,
    epochs=50,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data,
    callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 history_affine = workflow_affine.fit_offline(
#       2     data = training_data,
#       3     epochs=50,
#       4     num_batches_per_epoch=200,
#       5     batch_size=128,
#       6     validation_data = validation_data,
#       7     callbacks=[early_stop]
#       8 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py:722, in BasicWorkflow.fit_offline(self, data, epochs, batch_size, keep_optimizer, validation_data, augmentations, **kwargs)
#     677 """
#     678 Train the approximator offline using a fixed dataset. This approach will be faster than online training,
#     679 since no computation time is spent in generating new data for each batch, but it assumes that simulations
#    (...)    717     metric evolution over epochs.
#     718 """
#     720 dataset = OfflineDataset(data=data, batch_size=batch_size, adapter=self.adapter, augmentations=augmentations)
# --> 722 return self._fit(
#     723     dataset, epochs, strategy="online", keep_optimizer=keep_optimizer, validation_data=validation_data, **kwargs
#     724 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py:954, in BasicWorkflow._fit(self, dataset, epochs, strategy, keep_optimizer, validation_data, **kwargs)
#     951     self.approximator.compile(optimizer=self.optimizer, metrics=kwargs.pop("metrics", None))
#     953 try:
# --> 954     self.history = self.approximator.fit(
#     955         dataset=dataset, epochs=epochs, validation_data=validation_data, **kwargs
#     956     )
#     957     self._on_training_finished()
#     958     return self.history
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\continuous_approximator.py:316, in ContinuousApproximator.fit(self, *args, **kwargs)
#     264 def fit(self, *args, **kwargs):
#     265     """
#     266     Trains the approximator on the provided dataset or on-demand data generated from the given simulator.
#     267     If `dataset` is not provided, a dataset is built from the `simulator`.
#    (...)    314         If both `dataset` and `simulator` are provided or neither is provided.
#     315     """
# --> 316     return super().fit(*args, **kwargs, adapter=self.adapter)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\approximator.py:137, in Approximator.fit(self, dataset, simulator, **kwargs)
#     135     mock_data = keras.tree.map_structure(keras.ops.convert_to_tensor, mock_data)
#     136     mock_data_shapes = keras.tree.map_structure(keras.ops.shape, mock_data)
# --> 137     self.build(mock_data_shapes)
#     139 return super().fit(dataset=dataset, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:232, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     230 with obj._open_name_scope():
#     231     obj._path = current_path()
# --> 232     original_build_method(*args, **kwargs)
#     233 # Record build config.
#     234 signature = inspect.signature(original_build_method)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\continuous_approximator.py:90, in ContinuousApproximator.build(self, data_shapes)
#      88 # Build inference network if needed
#      89 if not self.inference_network.built:
# ---> 90     self.inference_network.build(data_shapes["inference_variables"], inference_conditions_shape)
#      92 # Set up standardization layers if requested
#      93 if self.standardize == "all":
#      94     # Only include variables present in data_shapes
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:232, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     230 with obj._open_name_scope():
#     231     obj._path = current_path()
# --> 232     original_build_method(*args, **kwargs)
#     233 # Record build config.
#     234 signature = inspect.signature(original_build_method)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\coupling_flow\coupling_flow.py:124, in CouplingFlow.build(self, xz_shape, conditions_shape)
#     122 def build(self, xz_shape, conditions_shape=None):
#     123     for layer in self.invertible_layers:
# --> 124         layer.build(xz_shape=xz_shape, conditions_shape=conditions_shape)
#     126     self.base_distribution.build(xz_shape)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:232, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     230 with obj._open_name_scope():
#     231     obj._path = current_path()
# --> 232     original_build_method(*args, **kwargs)
#     233 # Record build config.
#     234 signature = inspect.signature(original_build_method)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\coupling_flow\actnorm.py:33, in ActNorm.build(self, xz_shape, **kwargs)
#      32 def build(self, xz_shape: Shape, **kwargs):
# ---> 33     self.scale = self.add_weight(shape=(xz_shape[-1],), initializer="ones", name="scale")
#      34     self.bias = self.add_weight(shape=(xz_shape[-1],), initializer="zeros", name="bias")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:588, in Layer.add_weight(self, shape, initializer, dtype, trainable, autocast, regularizer, constraint, aggregation, overwrite_with_gradient, name)
#     586 variable.constraint = constraints.get(constraint)
#     587 variable.overwrite_with_gradient = overwrite_with_gradient
# --> 588 self._track_variable(variable)
#     589 return variable
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:1402, in Layer._track_variable(self, variable)
#    1400 def _track_variable(self, variable):
#    1401     if variable.trainable:
# -> 1402         self._tracker.add_to_store("trainable_variables", variable)
#    1403     else:
#    1404         self._tracker.add_to_store("non_trainable_variables", variable)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tracking.py:119, in Tracker.add_to_store(self, store_name, value)
#     117 def add_to_store(self, store_name, value):
#     118     if self.locked:
# --> 119         raise ValueError(self._lock_violation_msg)
#     120     self.config[store_name][1].append(value)
#     121     self.stored_ids[store_name].add(id(value))
#
# ValueError: You cannot add new elements of state (variables or sub-layers) to a layer that is already built. All state must be created in the `__init__()` method or in the `build()` method.

# %%
history_affine_MLP = workflow_affine.fit_offline(
    data = train_MLP,
    epochs=50,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = val_MLP,
    callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 history_affine_MLP = workflow_affine.fit_offline(
#       2     data = train_MLP,
#       3     epochs=50,
#       4     num_batches_per_epoch=200,
#       5     batch_size=128,
#       6     validation_data = val_MLP,
#       7     callbacks=[early_stop]
#       8 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py:722, in BasicWorkflow.fit_offline(self, data, epochs, batch_size, keep_optimizer, validation_data, augmentations, **kwargs)
#     677 """
#     678 Train the approximator offline using a fixed dataset. This approach will be faster than online training,
#     679 since no computation time is spent in generating new data for each batch, but it assumes that simulations
#    (...)    717     metric evolution over epochs.
#     718 """
#     720 dataset = OfflineDataset(data=data, batch_size=batch_size, adapter=self.adapter, augmentations=augmentations)
# --> 722 return self._fit(
#     723     dataset, epochs, strategy="online", keep_optimizer=keep_optimizer, validation_data=validation_data, **kwargs
#     724 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py:954, in BasicWorkflow._fit(self, dataset, epochs, strategy, keep_optimizer, validation_data, **kwargs)
#     951     self.approximator.compile(optimizer=self.optimizer, metrics=kwargs.pop("metrics", None))
#     953 try:
# --> 954     self.history = self.approximator.fit(
#     955         dataset=dataset, epochs=epochs, validation_data=validation_data, **kwargs
#     956     )
#     957     self._on_training_finished()
#     958     return self.history
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\continuous_approximator.py:316, in ContinuousApproximator.fit(self, *args, **kwargs)
#     264 def fit(self, *args, **kwargs):
#     265     """
#     266     Trains the approximator on the provided dataset or on-demand data generated from the given simulator.
#     267     If `dataset` is not provided, a dataset is built from the `simulator`.
#    (...)    314         If both `dataset` and `simulator` are provided or neither is provided.
#     315     """
# --> 316     return super().fit(*args, **kwargs, adapter=self.adapter)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\approximator.py:134, in Approximator.fit(self, dataset, simulator, **kwargs)
#     132 if not self.built:
#     133     logging.info("Building on a test batch.")
# --> 134     mock_data = dataset[0]
#     135     mock_data = keras.tree.map_structure(keras.ops.convert_to_tensor, mock_data)
#     136     mock_data_shapes = keras.tree.map_structure(keras.ops.shape, mock_data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\datasets\offline_dataset.py:124, in OfflineDataset.__getitem__(self, item)
#     121     raise RuntimeError(f"Could not apply augmentations of type {type(self.augmentations)}.")
#     123 if self.adapter is not None:
# --> 124     batch = self.adapter(batch, stage=self.stage)
#     126 return batch
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\adapter.py:182, in Adapter.__call__(self, data, inverse, stage, **kwargs)
#     179 if inverse:
#     180     return self.inverse(data, stage=stage, **kwargs)
# --> 182 return self.forward(data, stage=stage, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\adapter.py:113, in Adapter.forward(self, data, stage, log_det_jac, **kwargs)
#     111 if not log_det_jac:
#     112     for transform in self.transforms:
# --> 113         data = transform(data, stage=stage, **kwargs)
#     114     return data
#     116 log_det_jac = {}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\transforms\transform.py:16, in Transform.__call__(self, data, inverse, **kwargs)
#      13 if inverse:
#      14     return self.inverse(data, **kwargs)
# ---> 16 return self.forward(data, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\transforms\filter_transform.py:100, in FilterTransform.forward(self, data, strict, **kwargs)
#      98 for key, value in data.items():
#      99     if self._should_transform(key, value, inverse=False):
# --> 100         data[key] = self._apply_transform(key, value, inverse=False, **kwargs)
#     102 return data
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\transforms\filter_transform.py:155, in FilterTransform._apply_transform(self, key, value, inverse, **kwargs)
#     152 def _apply_transform(self, key: str, value: np.ndarray, inverse: bool = False, **kwargs) -> np.ndarray:
#     153     transform = self._get_transform(key)
# --> 155     return transform(value, inverse=inverse, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\transforms\elementwise_transform.py:14, in ElementwiseTransform.__call__(self, data, inverse, **kwargs)
#      11 if inverse:
#      12     return self.inverse(data, **kwargs)
# ---> 14 return self.forward(data, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\adapters\transforms\standardize.py:119, in Standardize.forward(self, data, stage, **kwargs)
#     114     if self.momentum is not None and stage == "training":
#     115         self.std = self.momentum * self.std + (1.0 - self.momentum) * np.std(
#     116             data, axis=self.axis, keepdims=True, ddof=1
#     117         )
# --> 119 mean = np.broadcast_to(self.mean, data.shape)
#     120 std = np.broadcast_to(self.std, data.shape)
#     122 return (data - mean) / std
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)    411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\stride_tricks.py:349, in _broadcast_to(array, shape, subok, readonly)
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#     348 extras = []
# --> 349 it = np.nditer(
#     350     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     351     op_flags=['readonly'], itershape=shape, order='C')
#     352 with it:
#     353     # never really has writebackifcopy semantics
#     354     broadcast = it.itviews[0]
#
# ValueError: input operand has more dimensions than allowed by the axis remapping

# %%
for k, v in train_MLP.items():
    print(k, v.shape)
# Out:
# H0 (100, 1)
# Omega_m (100, 1)
# n_s (100, 1)
# log_P_k_noisy (100, 256)

# %%
print(training_data["log_P_k_noisy"].shape)
print(training_data["H0"].shape)
print(training_data["Omega_m"].shape)
print(training_data["n_s"].shape)
# Out:
# (100, 256)
# (100, 1)
# (100, 1)
# (100, 1)

# %% [markdown]
# # Test Data

# %% [markdown]
# ### Sample posterior from the trained affine inference network
# Sample 1000 posterior samples from each simulated dataset of 300

# %%
post_samples_affine = workflow_affine.sample(conditions=test_data, num_samples=1000)

# %%
test_data['log_P_k_noisy'].shape
# Out:
# (10, 256, 1)

# %%
rank_affine = bf.diagnostics.plots.calibration_histogram(post_samples_affine, test_data)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %%
figures_affine = workflow_affine.plot_default_diagnostics(
    test_data=test_data,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# # 2) Inference with Spline coupling

# %%
inference_network_spline = bf.networks.CouplingFlow(transform="spline")

# %%
workflow_spline = bf.BasicWorkflow(
     inference_network=inference_network_spline,
     summary_network=summary_network,
     adapter=adapter_std,
     simulator=simulator
)

# %%
history_spline = workflow_spline.fit_offline(
    data = training_data,
    epochs=50,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data,
    callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 116s 116s/step - loss: 4.2568 - val_loss: 4.1377
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - loss: 3.9950 - val_loss: 4.9052
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step - loss: 4.1616 - val_loss: 5.0761
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 4.5113 - val_loss: 4.2223
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - loss: 3.9311 - val_loss: 3.5751
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 3.4472 - val_loss: 3.7196
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 3.4746 - val_loss: 3.8452
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 3.4178 - val_loss: 3.6583
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: 3.2078 - val_loss: 3.7368
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - loss: 3.2559 - val_loss: 3.7639

# %%
post_samples_spline = workflow_spline.sample(conditions=test_data, num_samples=1000)

# %%
# samples_spline["H0"][1]

# %%
plt.figure(figsize=(8, 4))
sns.histplot(post_samples_spline["H0"][-1], fill=True, color="skyblue", label="Posterior H₀")
#sns.kdeplot(samples_spline["Omega_m"][1], fill=True, color="skyblue", label="Posterior H₀")
#sns.kdeplot(samples_spline["n_s"][1], fill=True, color="skyblue", label="Posterior H₀")
plt.title("Posterior Density for $H_0$ (Test Case 0)")
plt.xlabel("$H_0$")
plt.ylabel("Density")
plt.grid(True)
plt.legend()
plt.show()

# %%
#str(test_data)

# %%
figures_spline = workflow_spline.plot_default_diagnostics(
    test_data=test_data,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# # 3) Flow matching

# %%
inference_network_flow = bf.networks.FlowMatching()

# %%
workflow_flow = bf.BasicWorkflow(
     inference_network=inference_network_flow,
     summary_network=summary_network,
     adapter=adapter_std,
     simulator=simulator
)

# %%
history_flow = workflow_flow.fit_offline(
    data = training_data,
    epochs=50,
    num_batches_per_epoch=200,
    batch_size=64,
    validation_data = validation_data,
    callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - loss: 2.2675 - val_loss: 1.3643
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - loss: 1.9206 - val_loss: 2.0036
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 2.0259 - val_loss: 1.6630
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - loss: 1.9620 - val_loss: 1.2694
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - loss: 1.9414 - val_loss: 0.9737
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 1.7221 - val_loss: 2.2318
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - loss: 2.1288 - val_loss: 2.0847
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 2.2010 - val_loss: 1.9007
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 2.2739 - val_loss: 1.7439
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 2.3125 - val_loss: 2.4074

# %%
figures_spline = workflow_flow.plot_default_diagnostics(
    test_data=test_data,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)
