# %% [markdown]
# # Imports

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower
import bayesflow as bf

import seaborn as sns
import time
print('Using CAMB %s installed at %s' % (camb.__version__, os.path.dirname(camb.__file__)))
# make sure the version and path is what you expect



from scipy.stats import beta
# Out:
# INFO:bayesflow:Using backend 'tensorflow'
# Using CAMB 1.6.1 installed at C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\camb

# %% [markdown]
# # Data generating process

# %% [markdown]
# ## Definitions

# %%
def generate_log10PK(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
    Generate noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-3 to ~3.16
        noise_level (float): relative Gaussian noise (e.g., 0.05 = 5%)

    Returns:
        noisy_P_k (np.array): noisy matter power spectrum at redshift z=0
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 4, 1024)


    ## To calculate the physical densities from the densities 
    # Baryon density
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    noise = rng.normal(0, noise_level * P_k)
    P_k_noisy = P_k + noise
    
    
    #Log_Pk_noisy = np.log10(P_k + noise)
    #Log_Pk = np.log10(P_k)

    #Log_kvals = np.log10(k_vals)

    return {
        'k' : k_vals,
        'P_k_clean' : P_k, 
        'P_k_noisy' : P_k_noisy
        #,
        #'Log_k': Log_kvals,
        #'Log_Pk_noisy': Log_Pk_noisy,
        #'Log_Pk_clean': Log_Pk
    }

# %% [markdown]
# ## Generating noisy observations
#
# $\theta^*$, True parameter from Planck 2018

# %%
# Define the true cosmological parameters
theta_star = {
    'H0': 67.4,
    'Omega_m': 0.315,
    'n_s': 0.965
}

# %%
# Generate the noisy power spectrum using theta_star
log_Pk_obs = generate_log10PK(
    H0=theta_star['H0'],
    Omega_m=theta_star['Omega_m'],
    n_s=theta_star['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    seed=42            # Optional, for reproducibility
)

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# ## Visualization
#
# P(k) vs k_vals

# %%
# Plot
plt.figure(figsize=(8, 5))
plt.plot(log_Pk_obs['Log_k'], log_Pk_obs['Log_Pk_clean'], label="Clean $\\log_{10}P(k)$", linewidth=2)
plt.plot(log_Pk_obs['Log_k'], log_Pk_obs['Log_Pk_noisy'], label="Noisy $\\log_{10}P(k)$", linewidth=1.5, alpha=0.7)
plt.xlabel("$\\log_{10}(k)$ [1/Mpc]")
plt.ylabel("$\\log_{10}(P(k))$")
plt.title("Log-Log Matter Power Spectrum with and without Noise")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
## Ploting the P_obs vs k_vals
plt.loglog(LoPk_obs['k'], Pk_obs['P_k_clean'], label='Clean')
plt.loglog(Pk_obs['k'], Pk_obs['P_k_noisy'], label='Noisy', alpha=0.6)
plt.xlabel('k [1/Mpc]')
plt.ylabel('P(k)')
plt.legend()
plt.show()

# %% [markdown]
# $f(P\_k))$, probability density of power spectrum

# %%
# Extract the noisy P(k) values
P_k_noisy = Pk_obs['P_k_noisy']

# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(P_k_noisy, bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Definitions part 2
#
# Sample from prior: $(\theta^{(s)}) \sim P(\theta)$

# %%
def prior(seed=None):
    rng = np.random.default_rng(seed)

    H0 = rng.uniform(30, 100)
    Omega_m = rng.uniform(0.1, 0.5)
    n_s = rng.uniform(0.7, 1.0)

    return {
        'H0': H0,
        'Omega_m': Omega_m,
        'n_s': n_s
    }

# %%
def prior_wide(seed=None):
    rng = np.random.default_rng(seed)



    # --- H0: Scaled Beta(2.5, 2.0) over [10, 100]
    a, b = 10, 100
    alpha, beta_param = 2.5, 2.0
    u = rng.beta(alpha, beta_param)  # u ∈ [0, 1]
    H0 = a + (b - a) * u                              # scale to [10, 100]


    
    Omega_m = rng.normal(loc=0.5, scale= 1)
    n_s = rng.normal(loc=0.5, scale=1)





    return {
        'H0': H0,
        'Omega_m': Omega_m,
        'n_s': n_s
    }

# %%
import numpy as np
from scipy.stats import beta

def beta_parameters_from_mean_variance(mean, variance):
    if not (0 < mean < 1):
        raise ValueError("Mean must be between 0 and 1 for Beta distribution.")
    if variance <= 0 or variance >= mean * (1 - mean):
        raise ValueError("Variance must be > 0 and < μ(1-μ) for valid Beta.")
    
    temp = (mean * (1 - mean)) / variance - 1
    alpha = mean * temp
    beta_param = (1 - mean) * temp
    return alpha, beta_param

def sample_H0_prior(mean, variance, h0_min=10, h0_max=100, size=1):
    """
    Samples from a scaled Beta prior for the Hubble constant H0.

    Parameters:
        mean (float): Desired mean of H0 prior (must be between h0_min and h0_max).
        variance (float): Desired variance of H0 prior.
        h0_min (float): Lower bound of H0 prior support.
        h0_max (float): Upper bound of H0 prior support.
        size (int): Number of samples to draw.

    Returns:
        np.ndarray: Samples from the prior.
    """
    # Convert to [0, 1] range
    mean_std = (mean - h0_min) / (h0_max - h0_min)
    var_std = variance / (h0_max - h0_min)**2

    # Get alpha and beta
    alpha, beta_param = beta_parameters_from_mean_variance(mean_std, var_std)

    # Sample in [0, 1], then scale to [h0_min, h0_max]
    samples = h0_min + (h0_max - h0_min) * np.random.beta(alpha, beta_param, size=size)
    return samples

# %%
samples = sample_H0_prior(mean=70, variance=25, h0_min=50, h0_max=90, size=1000)

import matplotlib.pyplot as plt
plt.hist(samples, bins=50, density=True)
plt.title("Samples from Scaled Beta Prior for $H_0$")
plt.xlabel("$H_0$ [km/s/Mpc]")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# Parameters
a, b = 10, 100
alpha, beta_param = 2, 1.5  # Flatter shape, same mean

# x-values in [10, 100]
x_vals = np.linspace(a, b, 500)

# True PDF of scaled Beta
scaled_beta_pdf = (1 / (b - a)) * beta.pdf((x_vals - a) / (b - a), alpha, beta_param)

# Plot
plt.plot(x_vals, scaled_beta_pdf, linewidth=2)
plt.title(f'Flatter PDF: Scaled Beta({alpha}, {beta_param}) over [{a}, {b}]')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# Sample from the Likelihood: $(y^{(s)}) \sim P(y | \theta)$
# The same function but with just one output of length of k_vals

# %%
def likelihood(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
        Same function as generate_PK(), the only difference is the single output "P_K_noisy".
        Redefining, just make it Likelihood.
        Also, note that n = len(k_vals) = 128
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 0.5, 1024) 


    ## To calculate the physical densities from the densities 
    
    # Baryon density (Well Know Constant from Plank 2018)
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    noise = rng.normal(0, noise_level * P_k)
    P_k_noisy = P_k + noise
    P_k_noisy = P_k_noisy.reshape(-1, 1)

    return {'P_k_noisy': P_k_noisy}

# %% [markdown]
# ### Testing Prior and Likelihood

# %%
theta_test = prior()
print(theta_test)
# Out:
# {'H0': 67.90484825668223, 'Omega_m': 0.17080395368971685, 'n_s': 0.7871714583476095}

# %%
# Generate the noisy power spectrum using theta_star
Pk_test = likelihood(
    H0=theta_test['H0'],
    Omega_m=theta_test['Omega_m'],
    n_s=theta_test['n_s'],
    noise_level=0.2   # 20% relative Gaussian noise
)

# %%
Pk_test['P_k_noisy'].shape
# Out:
# (1024, 1)

# %%
# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(Pk_test['P_k_noisy'].flatten(), bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# # Bayes Flow Workflow

# %% [markdown]
# ## Sample from the Joint Distribution $(\theta^{(s)}, y^{(s)}) \sim P(\theta, y)$

# %% [markdown]
# ### Simulator

# %%
simulator = bf.make_simulator([prior, likelihood])

# %%
# simulator.sample(2)

# %% [markdown]
# ###  Adapter

# %%
adapter = (
    bf.Adapter()
    .concatenate(["H0", "Omega_m", "n_s"], into="inference_variables")
    .rename("P_k_noisy", "summary_variables")
)

# %%
# adapter(dataset)

# %% [markdown]
# ### Summary Network

# %%
summary_network = bf.networks.DeepSet()

# %% [markdown]
# # 1) Affine Coupling Model

# %% [markdown]
# ### Affine Inference Network

# %%
inference_network = bf.networks.CouplingFlow()

# %% [markdown]
# ### Affine Workflow

# %%
workflow = bf.BasicWorkflow(
     inference_network=inference_network,
     summary_network=summary_network,
     adapter=adapter,
     simulator=simulator
)

# %% [markdown]
# ### Simulating S = 10,000 datasets

# %%
training_data = workflow.simulate(10000)
validation_data = workflow.simulate(1000)
test_data = workflow.simulate(500)

# %%
# history = workflow.fit_online(epochs=3, num_batches_per_epoch= 5, batch_size=64, validation_data=10)

# %%
training_data['P_k_noisy']
# Out:
# (10000, 128, 1)

# %% [markdown]
# Plotting any random simulated dataset just to know whether the simulator working properly

# %%
all_pks = training_data['P_k_noisy'][np.random.randint(1, 1000)]

# %%
plt.figure(figsize=(8, 5))
sns.histplot(all_pks, bins=100, kde=True, stat='density', color='skyblue', edgecolor='black')

plt.title('Density of All Simulated Noisy $P(k)$ Values')
plt.xlabel('$P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# This means the simulator is correct.

# %%
history = workflow.fit_offline(
    data = training_data,
    epochs=100,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - loss: 4.2592 - val_loss: 4.2337
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - loss: 4.2586 - val_loss: 4.2350
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 214ms/step - loss: 4.2638 - val_loss: 4.2352
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - loss: 4.2605 - val_loss: 4.2349
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2591 - val_loss: 4.2367
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - loss: 4.2561 - val_loss: 4.2351
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2596 - val_loss: 4.2347
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - loss: 4.2598 - val_loss: 4.2336
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2587 - val_loss: 4.2335
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2595 - val_loss: 4.2324
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - loss: 4.2582 - val_loss: 4.2330
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2591 - val_loss: 4.2323
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2570 - val_loss: 4.2317
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 211ms/step - loss: 4.2567 - val_loss: 4.2311
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2548 - val_loss: 4.2320
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - loss: 4.2587 - val_loss: 4.2321
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - loss: 4.2626 - val_loss: 4.2323
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2592 - val_loss: 4.2336
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - loss: 4.2566 - val_loss: 4.2320
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2566 - val_loss: 4.2317
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2583 - val_loss: 4.2324
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2605 - val_loss: 4.2333
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2608 - val_loss: 4.2331
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2551 - val_loss: 4.2321
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - loss: 4.2563 - val_loss: 4.2328
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2583 - val_loss: 4.2313
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2569 - val_loss: 4.2329
# Epoch 28/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2597 - val_loss: 4.2321
# Epoch 29/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2593 - val_loss: 4.2325
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - loss: 4.2585 - val_loss: 4.2327
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2572 - val_loss: 4.2324
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2603 - val_loss: 4.2317
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2575 - val_loss: 4.2320
# Epoch 34/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - loss: 4.2564 - val_loss: 4.2335
# Epoch 35/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2586 - val_loss: 4.2320
# Epoch 36/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 222ms/step - loss: 4.2572 - val_loss: 4.2317
# Epoch 37/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2575 - val_loss: 4.2318
# Epoch 38/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - loss: 4.2569 - val_loss: 4.2334
# Epoch 39/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 221ms/step - loss: 4.2562 - val_loss: 4.2317
# Epoch 40/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2621 - val_loss: 4.2346
# Epoch 41/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2547 - val_loss: 4.2328
# Epoch 42/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2579 - val_loss: 4.2325
# Epoch 43/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2527 - val_loss: 4.2317
# Epoch 44/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2567 - val_loss: 4.2322
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2633 - val_loss: 4.2321
# Epoch 46/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2551 - val_loss: 4.2320
# Epoch 47/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2587 - val_loss: 4.2321
# Epoch 48/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2595 - val_loss: 4.2322
# Epoch 49/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - loss: 4.2560 - val_loss: 4.2311
# Epoch 50/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2583 - val_loss: 4.2326
# Epoch 51/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - loss: 4.2603 - val_loss: 4.2322
# Epoch 52/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2604 - val_loss: 4.2324
# Epoch 53/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - loss: 4.2578 - val_loss: 4.2322
# Epoch 54/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2592 - val_loss: 4.2323
# Epoch 55/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - loss: 4.2556 - val_loss: 4.2327
# Epoch 56/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 4.2597 - val_loss: 4.2323
# Epoch 57/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - loss: 4.2572 - val_loss: 4.2319
# Epoch 58/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - loss: 4.2566 - val_loss: 4.2322
# Epoch 59/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - loss: 4.2531 - val_loss: 4.2313
# Epoch 60/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - loss: 4.2582 - val_loss: 4.2325
# Epoch 61/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - loss: 4.2588 - val_loss: 4.2319
# Epoch 62/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2582 - val_loss: 4.2319
# Epoch 63/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2558 - val_loss: 4.2317
# Epoch 64/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2560 - val_loss: 4.2318
# Epoch 65/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2570 - val_loss: 4.2322
# Epoch 66/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - loss: 4.2600 - val_loss: 4.2318
# Epoch 67/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - loss: 4.2568 - val_loss: 4.2317
# Epoch 68/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - loss: 4.2545 - val_loss: 4.2319
# Epoch 69/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2588 - val_loss: 4.2318
# Epoch 70/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - loss: 4.2551 - val_loss: 4.2320
# Epoch 71/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2596 - val_loss: 4.2317
# Epoch 72/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - loss: 4.2575 - val_loss: 4.2321
# Epoch 73/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - loss: 4.2588 - val_loss: 4.2317
# Epoch 74/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - loss: 4.2584 - val_loss: 4.2319
# Epoch 75/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - loss: 4.2563 - val_loss: 4.2320
# Epoch 76/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - loss: 4.2552 - val_loss: 4.2319
# Epoch 77/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2570 - val_loss: 4.2317
# Epoch 78/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - loss: 4.2570 - val_loss: 4.2319
# Epoch 79/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - loss: 4.2575 - val_loss: 4.2318
# Epoch 80/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - loss: 4.2577 - val_loss: 4.2319
# Epoch 81/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - loss: 4.2572 - val_loss: 4.2318
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - loss: 4.2542 - val_loss: 4.2319
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - loss: 4.2599 - val_loss: 4.2320
# Epoch 84/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - loss: 4.2547 - val_loss: 4.2319
# Epoch 85/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - loss: 4.2523 - val_loss: 4.2318
# Epoch 86/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - loss: 4.2580 - val_loss: 4.2318
# Epoch 87/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - loss: 4.2568 - val_loss: 4.2318
# Epoch 88/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - loss: 4.2594 - val_loss: 4.2319
# Epoch 89/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - loss: 4.2554 - val_loss: 4.2319
# Epoch 90/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - loss: 4.2561 - val_loss: 4.2319
# Epoch 91/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 244ms/step - loss: 4.2579 - val_loss: 4.2319
# Epoch 92/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - loss: 4.2570 - val_loss: 4.2319
# Epoch 93/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - loss: 4.2593 - val_loss: 4.2319
# Epoch 94/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - loss: 4.2558 - val_loss: 4.2319
# Epoch 95/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - loss: 4.2540 - val_loss: 4.2319
# Epoch 96/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 248ms/step - loss: 4.2545 - val_loss: 4.2318
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 240ms/step - loss: 4.2590 - val_loss: 4.2318
# Epoch 98/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - loss: 4.2576 - val_loss: 4.2318
# Epoch 99/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - loss: 4.2587 - val_loss: 4.2318
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 253ms/step - loss: 4.2576 - val_loss: 4.2318

# %%
history = workflow.fit_offline(
    data=training_data, 
    epochs=10, 
    batch_size=64, 
    validation_data = validation_data
)

# %%
f = bf.diagnostics.plots.loss(history)

# %% [markdown]
# # Test Data

# %%
# Set the number of posterior draws you want to get
num_datasets = 300
num_samples = 1000

# Simulate 300 scenarios
test_data = workflow.simulate(num_datasets)

# %% [markdown]
# ### Sample posterior from the trained affine inference network
# Sample 1000 posterior samples from each simulated dataset of 300

# %%
samples = workflow.sample(conditions=test_data, num_samples=num_samples)

# %%
f = bf.diagnostics.plots.calibration_histogram(samples, test_data)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %%
f = bf.diagnostics.plots.calibration_ecdf(samples, test_data, difference=True)

# %%
f = bf.diagnostics.plots.recovery(samples, test_data)

# %%
figures = workflow.plot_default_diagnostics(
    test_data=300,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# # 2) Inference with Spline coupling

# %%
simulator_clip = bf.make_simulator([prior_clip, likelihood])

# %%
simulator_clip.simulate(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 simulator_clip.simulate(1)
#
# AttributeError: 'SequentialSimulator' object has no attribute 'simulate'

# %%
summary_network = bf.networks.DeepSet()

# %%
inference_network_spline = bf.networks.CouplingFlow(transform="spline")

# %%
workflow_spline = bf.BasicWorkflow(
     inference_network=inference_network_spline,
     summary_network=summary_network,
     adapter=adapter,
     simulator=simulator_clip
)

# %% [markdown]
# ## Sampling Datasets

# %%
# Start timer
start_time = time.time()

training_data = workflow_spline.simulate(1000)

# End timer
end_time = time.time()

# Compute elapsed time
sampling_time = end_time - start_time
print(f"Sampling took {sampling_time:.2f} seconds")

# %%
# Start timer
start_time = time.time()

validation_data = workflow_spline.simulate(200)

# End timer
end_time = time.time()

# Compute elapsed time
sampling_time = end_time - start_time
print(f"Sampling took {sampling_time:.2f} seconds")

# %%
# Start timer
start_time = time.time()

test_data = workflow_spline.simulate(1000)

# End timer
end_time = time.time()

# Compute elapsed time
sampling_time = end_time - start_time
print(f"Sampling took {sampling_time:.2f} seconds")

# %%
history_spline = workflow_spline.fit_offline(
    data = training_data,
    epochs=100,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
)

# %%
samples_spline = workflow_spline.sample(conditions=test_data, num_samples=1000)

# %%
samples_spline["H0"][1]
# Out:
# array([[ 96.97522 ],
#        [ 91.376785],
#        [ 61.519474],
#        [ 69.11122 ],
#        [ 65.50477 ],
#        [ 37.60312 ],
#        [ 52.865063],
#        [ 96.06464 ],
#        [ 59.85261 ],
#        [ 53.270622],
#        [ 81.887375],
#        [ 47.987576],
#        [ 52.396393],
#        [ 88.14424 ],
#        [ 40.49973 ],
#        [ 78.88243 ],
#        [ 69.94385 ],
#        [ 77.277596],
#        [ 86.127716],
#        [ 40.81736 ],
#        [ 46.233486],
#        [ 40.58882 ],
#        [ 72.36194 ],
#        [ 45.803337],
#        [ 47.23111 ],
#        [ 68.5404  ],
#        [ 71.32838 ],
#        [ 58.90501 ],
#        [ 96.78467 ],
#        [ 74.587204],
#        [ 77.29596 ],
#        [ 71.51164 ],
#        [ 48.862778],
#        [ 71.50632 ],
#        [ 78.560646],
#        [ 77.65566 ],
#        [ 56.04958 ],
#        [ 64.808624],
#        [ 76.16447 ],
#        [ 98.44273 ],
#        [ 94.890686],
#        [ 40.056175],
#        [ 36.50995 ],
#        [ 43.53531 ],
#        [ 85.159225],
#        [ 51.396862],
#        [ 69.908165],
#        [ 53.304787],
#        [ 69.610085],
#        [ 89.91718 ],
#        [ 64.93091 ],
#        [ 49.67279 ],
#        [ 54.903473],
#        [ 85.47199 ],
#        [ 44.736977],
#        [ 50.55278 ],
#        [ 90.26518 ],
#        [ 71.29765 ],
#        [ 44.30546 ],
#        [ 36.235817],
#        [ 47.24199 ],
#        [ 56.034798],
#        [ 92.820755],
#        [ 35.475952],
#        [ 44.018818],
#        [ 78.54139 ],
#        [ 77.332344],
#        [ 54.294315],
#        [ 97.483986],
#        [ 78.54471 ],
#        [ 85.44034 ],
#        [ 63.98624 ],
#        [ 41.79119 ],
#        [ 90.69429 ],
#        [ 66.315445],
#        [ 77.89652 ],
#        [ 78.054306],
#        [ 49.042747],
#        [ 48.82103 ],
#        [ 64.54413 ],
#        [ 35.964043],
#        [ 59.324715],
#        [ 74.265564],
#        [ 53.13793 ],
#        [ 63.690838],
#        [ 65.76317 ],
#        [ 69.43575 ],
#        [ 78.571556],
#        [ 71.61613 ],
#        [ 38.857933],
#        [ 90.59567 ],
#        [ 46.369125],
#        [ 64.88734 ],
#        [ 73.24812 ],
#        [ 63.955757],
#        [ 49.546288],
#        [ 71.27035 ],
#        [ 97.68823 ],
#        [ 66.169075],
#        [ 53.1842  ],
#        [ 53.991005],
#        [ 74.73101 ],
#        [ 44.689125],
#        [ 77.77937 ],
#        [ 94.25622 ],
#        [ 84.090706],
#        [ 77.76375 ],
#        [ 40.142033],
#        [ 97.87488 ],
#        [ 80.10061 ],
#        [ 78.59221 ],
#        [ 76.18453 ],
#        [ 83.5591  ],
#        [ 90.89002 ],
#        [ 35.615067],
#        [ 40.85381 ],
#        [ 49.90136 ],
#        [ 45.237335],
#        [ 73.08075 ],
#        [ 52.52066 ],
#        [ 93.05221 ],
#        [ 53.398743],
#        [ 81.789   ],
#        [ 46.172974],
#        [ 70.67354 ],
#        [ 77.932045],
#        [ 76.74179 ],
#        [ 82.80856 ],
#        [ 97.74066 ],
#        [ 81.17237 ],
#        [ 74.55107 ],
#        [ 85.18819 ],
#        [ 96.15874 ],
#        [ 70.64935 ],
#        [ 77.634476],
#        [ 75.42852 ],
#        [ 65.19463 ],
#        [ 63.95828 ],
#        [ 51.077713],
#        [ 60.627842],
#        [ 36.896126],
#        [ 53.95037 ],
#        [ 53.368626],
#        [ 62.95331 ],
#        [ 73.23697 ],
#        [ 97.211426],
#        [ 57.386307],
#        [ 44.49855 ],
#        [ 44.297295],
#        [ 54.61447 ],
#        [ 39.950394],
#        [ 41.946884],
#        [ 54.86663 ],
#        [ 88.53836 ],
#        [ 33.22196 ],
#        [ 61.72106 ],
#        [ 63.106487],
#        [ 60.16356 ],
#        [ 74.58666 ],
#        [ 55.10308 ],
#        [ 71.77925 ],
#        [ 81.79488 ],
#        [ 66.377716],
#        [ 45.567574],
#        [ 68.89675 ],
#        [ 70.208084],
#        [ 74.747955],
#        [ 73.89558 ],
#        [ 92.28019 ],
#        [ 35.016464],
#        [ 82.729065],
#        [ 83.794235],
#        [ 47.10659 ],
#        [ 95.87674 ],
#        [ 32.61767 ],
#        [ 48.03154 ],
#        [ 67.88802 ],
#        [ 66.059944],
#        [ 46.797928],
#        [ 38.254837],
#        [ 75.63257 ],
#        [ 35.54049 ],
#        [ 59.3781  ],
#        [ 92.70941 ],
#        [ 67.224266],
#        [ 73.030594],
#        [ 44.990776],
#        [ 70.50621 ],
#        [ 85.08435 ],
#        [ 65.4027  ],
#        [ 71.05467 ],
#        [ 51.94094 ],
#        [ 80.76435 ],
#        [ 36.461494],
#        [ 77.97909 ],
#        [ 62.337273],
#        [ 36.50184 ],
#        [ 92.00311 ],
#        [ 70.574486],
#        [ 64.496216],
#        [ 82.77457 ],
#        [ 57.089363],
#        [ 71.455956],
#        [ 66.55002 ],
#        [ 33.99185 ],
#        [ 98.92162 ],
#        [ 79.40546 ],
#        [ 63.725006],
#        [ 76.82162 ],
#        [ 75.65816 ],
#        [ 66.54812 ],
#        [ 83.752594],
#        [ 36.2537  ],
#        [ 73.28132 ],
#        [ 75.582504],
#        [ 94.95813 ],
#        [ 87.29477 ],
#        [ 62.433258],
#        [ 63.692608],
#        [ 33.90194 ],
#        [ 40.31897 ],
#        [ 70.93813 ],
#        [ 68.1661  ],
#        [ 94.67248 ],
#        [ 45.819366],
#        [ 59.93733 ],
#        [ 53.072292],
#        [ 92.12677 ],
#        [ 75.699265],
#        [ 78.34758 ],
#        [ 77.94305 ],
#        [ 85.78483 ],
#        [ 83.81972 ],
#        [ 36.659615],
#        [ 75.177864],
#        [ 85.56054 ],
#        [ 87.841965],
#        [ 89.28682 ],
#        [ 98.62613 ],
#        [ 65.77414 ],
#        [ 38.474953],
#        [ 67.16465 ],
#        [ 67.798836],
#        [ 33.85959 ],
#        [ 60.59766 ],
#        [ 85.87337 ],
#        [ 98.62132 ],
#        [ 40.566963],
#        [ 88.912155],
#        [ 65.37831 ],
#        [ 39.879333],
#        [ 69.92674 ],
#        [ 98.96602 ],
#        [ 89.147804],
#        [ 73.81727 ],
#        [ 54.948948],
#        [ 80.08294 ],
#        [ 55.611153],
#        [ 53.620583],
#        [ 58.14752 ],
#        [ 61.103073],
#        [ 81.84648 ],
#        [ 74.82443 ],
#        [ 35.64657 ],
#        [ 64.6036  ],
#        [ 91.94894 ],
#        [ 76.88286 ],
#        [ 36.4104  ],
#        [ 31.826546],
#        [ 62.253624],
#        [ 65.755585],
#        [ 78.89533 ],
#        [ 36.247833],
#        [ 54.41737 ],
#        [ 96.249176],
#        [ 92.60798 ],
#        [ 83.50229 ],
#        [ 74.77042 ],
#        [ 71.5692  ],
#        [ 75.80227 ],
#        [ 54.68726 ],
#        [ 92.75016 ],
#        [ 75.02608 ],
#        [ 55.625698],
#        [ 48.182594],
#        [ 54.729446],
#        [ 99.37744 ],
#        [ 43.491634],
#        [ 97.683304],
#        [ 80.46135 ],
#        [ 60.269016],
#        [ 41.263393],
#        [ 68.87012 ],
#        [ 93.19574 ],
#        [ 79.6788  ],
#        [ 56.551506],
#        [ 72.52977 ],
#        [ 51.511314],
#        [ 88.3009  ],
#        [ 78.74974 ],
#        [ 44.286392],
#        [ 48.27098 ],
#        [ 91.12029 ],
#        [ 79.93813 ],
#        [ 74.84316 ],
#        [ 37.9935  ],
#        [ 85.98678 ],
#        [ 76.26035 ],
#        [ 97.06187 ],
#        [ 90.75807 ],
#        [ 85.572174],
#        [ 43.666626],
#        [ 46.552433],
#        [ 52.400597],
#        [ 87.989456],
#        [ 63.166073],
#        [ 79.120804],
#        [ 57.375336],
#        [ 69.972626],
#        [ 67.57981 ],
#        [ 63.36301 ],
#        [ 67.32966 ],
#        [ 35.783997],
#        [ 68.59299 ],
#        [ 98.71504 ],
#        [ 52.129578],
#        [ 67.48904 ],
#        [ 69.09684 ],
#        [ 45.22853 ],
#        [ 64.85831 ],
#        [ 37.02414 ],
#        [ 36.908916],
#        [ 55.691624],
#        [ 88.731155],
#        [ 69.66955 ],
#        [ 41.84468 ],
#        [ 31.621006],
#        [ 52.834282],
#        [ 46.49637 ],
#        [ 93.55235 ],
#        [ 65.31092 ],
#        [ 51.678444],
#        [ 86.120056],
#        [ 35.534504],
#        [ 78.77821 ],
#        [ 55.386917],
#        [ 52.138817],
#        [ 41.280636],
#        [ 79.11308 ],
#        [ 87.43461 ],
#        [ 80.03521 ],
#        [ 53.789825],
#        [ 41.024067],
#        [ 87.74427 ],
#        [ 54.87738 ],
#        [ 95.4958  ],
#        [ 46.930656],
#        [ 71.50555 ],
#        [ 36.266243],
#        [ 63.904495],
#        [ 90.09311 ],
#        [ 41.3083  ],
#        [ 55.313206],
#        [ 52.088615],
#        [ 83.90372 ],
#        [ 96.99224 ],
#        [ 66.68205 ],
#        [ 87.59119 ],
#        [ 70.31633 ],
#        [ 37.49691 ],
#        [ 52.251045],
#        [ 46.886314],
#        [ 71.87209 ],
#        [ 36.85497 ],
#        [ 92.872696],
#        [ 97.4465  ],
#        [ 62.10558 ],
#        [ 35.22458 ],
#        [ 66.86999 ],
#        [ 74.19484 ],
#        [ 52.85935 ],
#        [ 55.300804],
#        [ 82.66644 ],
#        [ 58.00298 ],
#        [ 70.425545],
#        [ 85.31752 ],
#        [ 91.01191 ],
#        [ 81.25455 ],
#        [ 79.13842 ],
#        [ 39.571655],
#        [ 89.409454],
#        [ 53.81092 ],
#        [ 71.99597 ],
#        [ 43.763702],
#        [ 52.833412],
#        [ 97.40222 ],
#        [ 78.75843 ],
#        [ 45.06424 ],
#        [ 46.60654 ],
#        [ 91.32705 ],
#        [ 86.20769 ],
#        [ 86.103165],
#        [ 86.37122 ],
#        [ 60.398182],
#        [ 93.42566 ],
#        [ 78.36841 ],
#        [ 47.18722 ],
#        [ 78.586044],
#        [ 89.50424 ],
#        [ 84.95375 ],
#        [ 52.30501 ],
#        [ 43.69628 ],
#        [ 70.50124 ],
#        [ 80.91679 ],
#        [ 86.80887 ],
#        [ 37.384407],
#        [ 94.00838 ],
#        [ 71.431076],
#        [ 38.15877 ],
#        [ 44.394676],
#        [ 82.91832 ],
#        [ 73.09252 ],
#        [ 95.319435],
#        [ 84.2499  ],
#        [ 83.89872 ],
#        [ 69.00332 ],
#        [ 73.20039 ],
#        [ 34.78656 ],
#        [ 51.008194],
#        [ 83.96312 ],
#        [ 56.226036],
#        [ 64.84683 ],
#        [ 91.42439 ],
#        [ 57.274445],
#        [ 49.3368  ],
#        [ 49.580948],
#        [ 88.90919 ],
#        [ 66.50313 ],
#        [ 63.376873],
#        [ 57.550972],
#        [ 69.97678 ],
#        [ 56.67229 ],
#        [ 38.81058 ],
#        [ 54.60811 ],
#        [ 96.393585],
#        [ 13.569267],
#        [ 73.40331 ],
#        [ 99.10627 ],
#        [ 44.456097],
#        [ 73.077736],
#        [ 96.461006],
#        [ 98.99629 ],
#        [ 78.119316],
#        [ 78.43969 ],
#        [ 92.987755],
#        [ 93.95641 ],
#        [ 35.72898 ],
#        [ 88.62401 ],
#        [ 90.624565],
#        [ 68.25111 ],
#        [ 86.979324],
#        [ 83.35624 ],
#        [ 36.2092  ],
#        [ 94.0645  ],
#        [ 35.45571 ],
#        [ 73.5686  ],
#        [ 92.41623 ],
#        [ 44.331055],
#        [ 64.59442 ],
#        [ 61.071598],
#        [ 53.92797 ],
#        [ 58.680634],
#        [ 79.493706],
#        [ 37.998474],
#        [ 95.77424 ],
#        [ 38.67207 ],
#        [ 40.570557],
#        [ 96.694824],
#        [ 71.10786 ],
#        [ 79.83756 ],
#        [ 62.589306],
#        [ 76.912766],
#        [ 76.825775],
#        [ 88.22055 ],
#        [ 86.04875 ],
#        [ 39.8859  ],
#        [ 41.20385 ],
#        [ 93.588394],
#        [ 86.86734 ],
#        [ 60.403507],
#        [ 57.728027],
#        [ 54.218166],
#        [ 73.333916],
#        [ 78.37854 ],
#        [ 85.79605 ],
#        [ 56.64501 ],
#        [ 68.35699 ],
#        [ 81.65088 ],
#        [ 68.84239 ],
#        [ 50.522316],
#        [ 89.126495],
#        [ 68.15588 ],
#        [ 58.73581 ],
#        [ 85.26767 ],
#        [ 38.04915 ],
#        [ 96.59415 ],
#        [ 74.20148 ],
#        [ 71.43252 ],
#        [ 93.65123 ],
#        [ 93.31655 ],
#        [ 86.67064 ],
#        [ 84.93599 ],
#        [ 32.197742],
#        [ 43.631668],
#        [ 93.84673 ],
#        [ 65.17309 ],
#        [ 82.67041 ],
#        [ 58.54344 ],
#        [ 71.74796 ],
#        [ 68.132576],
#        [ 36.44152 ],
#        [ 40.850853],
#        [ 46.52578 ],
#        [ 86.63626 ],
#        [ 78.37087 ],
#        [ 47.214752],
#        [ 80.89365 ],
#        [ 51.45784 ],
#        [ 76.14576 ],
#        [ 77.304184],
#        [ 36.305096],
#        [ 90.7076  ],
#        [ 80.54871 ],
#        [ 81.27402 ],
#        [ 95.4293  ],
#        [ 41.44406 ],
#        [ 46.79091 ],
#        [ 66.00667 ],
#        [ 77.84677 ],
#        [ 89.2684  ],
#        [ 62.63398 ],
#        [ 73.772644],
#        [ 97.22008 ],
#        [ 40.73575 ],
#        [ 85.66933 ],
#        [ 77.55016 ],
#        [ 58.35194 ],
#        [ 64.46369 ],
#        [ 91.16668 ],
#        [ 54.8995  ],
#        [ 93.608   ],
#        [ 76.28345 ],
#        [ 76.85659 ],
#        [ 81.01602 ],
#        [ 64.86705 ],
#        [ 71.67792 ],
#        [ 86.02562 ],
#        [ 60.887924],
#        [ 88.22624 ],
#        [ 88.20009 ],
#        [ 76.631165],
#        [ 89.48161 ],
#        [ 49.819977],
#        [ 82.92205 ],
#        [ 79.53478 ],
#        [ 41.32882 ],
#        [ 85.465   ],
#        [ 55.00145 ],
#        [ 99.27424 ],
#        [ 74.097694],
#        [ 90.76583 ],
#        [ 50.321243],
#        [ 67.019066],
#        [ 39.33675 ],
#        [ 41.906467],
#        [ 52.237247],
#        [ 90.51442 ],
#        [ 98.57034 ],
#        [ 76.54591 ],
#        [ 72.21859 ],
#        [ 35.73835 ],
#        [ 86.92733 ],
#        [ 75.97748 ],
#        [ 39.63736 ],
#        [ 80.47231 ],
#        [ 77.2613  ],
#        [ 37.960735],
#        [ 72.47655 ],
#        [ 54.507507],
#        [ 11.049286],
#        [ 77.88054 ],
#        [ 47.393143],
#        [ 82.45062 ],
#        [ 52.3152  ],
#        [ 40.350555],
#        [ 46.360153],
#        [ 98.81359 ],
#        [ 52.57415 ],
#        [ 77.24929 ],
#        [ 81.26143 ],
#        [ 61.88647 ],
#        [ 55.46432 ],
#        [ 82.11549 ],
#        [ 85.81122 ],
#        [ 85.57195 ],
#        [ 79.04746 ],
#        [ 77.603714],
#        [ 53.313976],
#        [ 75.88588 ],
#        [ 91.85115 ],
#        [ 45.48231 ],
#        [ 38.39785 ],
#        [ 85.01538 ],
#        [ 72.48826 ],
#        [ 82.94145 ],
#        [ 78.144424],
#        [ 95.55055 ],
#        [ 83.44888 ],
#        [ 86.527954],
#        [ 99.06206 ],
#        [ 58.28745 ],
#        [ 96.34091 ],
#        [ 51.744106],
#        [ 54.56997 ],
#        [ 63.08687 ],
#        [ 92.149826],
#        [ 75.77493 ],
#        [ 81.93472 ],
#        [ 40.995167],
#        [ 83.498474],
#        [ 67.155075],
#        [ 78.88608 ],
#        [ 89.93289 ],
#        [ 75.99398 ],
#        [ 54.34973 ],
#        [ 63.21764 ],
#        [ 75.75296 ],
#        [ 58.85092 ],
#        [ 55.195236],
#        [ 81.85191 ],
#        [ 42.869873],
#        [ 68.3012  ],
#        [ 45.03929 ],
#        [ 85.82025 ],
#        [ 98.47136 ],
#        [ 37.03074 ],
#        [ 98.51561 ],
#        [ 59.261505],
#        [ 52.71704 ],
#        [ 92.51313 ],
#        [ 61.14634 ],
#        [ 57.683414],
#        [ 53.2642  ],
#        [ 90.17534 ],
#        [ 56.945953],
#        [ 45.635086],
#        [ 72.74261 ],
#        [ 53.28162 ],
#        [ 43.66896 ],
#        [ 77.18441 ],
#        [ 32.185234],
#        [ 80.813644],
#        [ 95.30255 ],
#        [ 33.945637],
#        [ 63.839233],
#        [ 37.749844],
#        [ 71.88344 ],
#        [ 79.25706 ],
#        [ 36.241768],
#        [ 93.5743  ],
#        [ 77.279724],
#        [ 24.98079 ],
#        [ 33.866703],
#        [ 33.98876 ],
#        [ 89.765976],
#        [ 90.60909 ],
#        [ 53.26638 ],
#        [ 67.667915],
#        [ 98.93934 ],
#        [ 62.18102 ],
#        [ 78.50253 ],
#        [ 44.60634 ],
#        [ 60.250183],
#        [ 57.757355],
#        [ 82.94613 ],
#        [ 45.913918],
#        [ 83.638504],
#        [ 85.725555],
#        [ 35.551765],
#        [ 65.62262 ],
#        [ 51.955532],
#        [ 35.563385],
#        [ 92.518105],
#        [ 78.90211 ],
#        [ 55.801395],
#        [ 62.387707],
#        [ 42.57437 ],
#        [ 84.88618 ],
#        [ 92.35086 ],
#        [ 49.7922  ],
#        [ 47.341892],
#        [ 82.49143 ],
#        [ 77.63543 ],
#        [ 33.057983],
#        [ 35.447987],
#        [ 65.03412 ],
#        [ 45.05735 ],
#        [ 42.409363],
#        [ 32.613995],
#        [ 79.71218 ],
#        [ 56.684166],
#        [ 30.784218],
#        [ 39.281036],
#        [ 97.13314 ],
#        [ 37.982582],
#        [ 32.718307],
#        [ 39.77526 ],
#        [ 67.30115 ],
#        [ 77.8483  ],
#        [ 34.631824],
#        [ 59.955025],
#        [ 99.872345],
#        [ 88.6632  ],
#        [ 52.948612],
#        [ 98.10683 ],
#        [ 76.74894 ],
#        [ 79.98247 ],
#        [ 83.28934 ],
#        [ 81.38924 ],
#        [ 42.587727],
#        [ 85.13096 ],
#        [ 89.763626],
#        [ 75.49642 ],
#        [ 86.91225 ],
#        [ 50.197243],
#        [ 54.485268],
#        [ 76.50829 ],
#        [ 84.71948 ],
#        [ 59.37891 ],
#        [ 71.234184],
#        [ 60.82062 ],
#        [ 61.119736],
#        [ 70.56133 ],
#        [ 55.078045],
#        [ 64.29184 ],
#        [ 69.710976],
#        [ 46.686787],
#        [ 36.84043 ],
#        [ 41.403   ],
#        [ 77.85242 ],
#        [ 41.889915],
#        [ 76.6416  ],
#        [ 81.869125],
#        [ 51.744606],
#        [ 54.78337 ],
#        [ 61.60537 ],
#        [ 91.59427 ],
#        [ 56.008873],
#        [ 43.70089 ],
#        [ 96.3938  ],
#        [ 81.10437 ],
#        [ 49.240154],
#        [ 42.52932 ],
#        [ 52.124546],
#        [ 48.60176 ],
#        [ 44.71503 ],
#        [ 74.916595],
#        [ 85.15918 ],
#        [ 68.28677 ],
#        [ 82.60806 ],
#        [ 53.546917],
#        [ 77.62448 ],
#        [ 50.056915],
#        [ 70.3222  ],
#        [101.34748 ],
#        [ 79.04648 ],
#        [ 96.10277 ],
#        [ 67.264656],
#        [ 71.24702 ],
#        [ 49.768787],
#        [ 44.92383 ],
#        [ 47.31766 ],
#        [ 86.06712 ],
#        [ 95.389145],
#        [ 97.295944],
#        [ 50.353806],
#        [ 94.64979 ],
#        [ 93.39461 ],
#        [ 61.292755],
#        [ 94.73011 ],
#        [ 60.108673],
#        [ 84.94255 ],
#        [ 58.386135],
#        [ 36.11428 ],
#        [ 87.46349 ],
#        [ 40.45794 ],
#        [ 40.460846],
#        [ 34.90999 ],
#        [ 38.980263],
#        [ 79.07537 ],
#        [ 52.97188 ],
#        [ 40.51626 ],
#        [ 42.66583 ],
#        [ 98.89528 ],
#        [ 77.4268  ],
#        [ 78.28788 ],
#        [ 90.244675],
#        [ 36.076576],
#        [ 78.59011 ],
#        [ 85.13005 ],
#        [ 58.326206],
#        [ 40.842598],
#        [ 90.41485 ],
#        [ 48.421055],
#        [ 43.409904],
#        [ 32.8308  ],
#        [ 63.731323],
#        [ 71.15598 ],
#        [ 37.92966 ],
#        [ 64.96978 ],
#        [ 47.208275],
#        [ 68.9259  ],
#        [ 71.94066 ],
#        [ 79.94503 ],
#        [ 35.60873 ],
#        [ 35.29816 ],
#        [ 95.90907 ],
#        [ 96.647026],
#        [ 78.72057 ],
#        [ 52.664642],
#        [ 73.570274],
#        [ 62.866837],
#        [ 61.971985],
#        [ 76.20584 ],
#        [ 17.208263],
#        [ 80.6899  ],
#        [ 51.14039 ],
#        [ 60.366856],
#        [ 91.25657 ],
#        [ 71.349846],
#        [ 66.06038 ],
#        [ 53.20339 ],
#        [ 73.042206],
#        [ 51.342266],
#        [ 84.18407 ],
#        [ 78.25763 ],
#        [ 98.16919 ],
#        [ 90.27291 ],
#        [ 87.06228 ],
#        [ 63.136444],
#        [ 51.619247],
#        [ 85.65113 ],
#        [ 92.616684],
#        [ 50.246468],
#        [ 94.01626 ],
#        [ 40.575138],
#        [ 83.07667 ],
#        [ 87.81009 ],
#        [ 71.2105  ],
#        [ 91.67591 ],
#        [ 44.244114],
#        [ 63.561504],
#        [ 63.09241 ],
#        [ 82.590836],
#        [ 62.320293],
#        [ 89.5845  ],
#        [ 35.35865 ],
#        [ 78.817375],
#        [ 52.38343 ],
#        [ 52.91066 ],
#        [ 79.36453 ],
#        [ 51.850113],
#        [ 39.272278],
#        [ 80.44564 ],
#        [ 89.690315],
#        [ 87.67583 ],
#        [ 42.2968  ],
#        [ 75.62076 ],
#        [ 88.84983 ],
#        [ 98.49004 ],
#        [ 64.681366],
#        [ 91.97962 ],
#        [ 51.75664 ],
#        [ 63.979427],
#        [ 82.13072 ],
#        [ 94.14215 ],
#        [ 47.768723],
#        [ 69.95097 ],
#        [ 96.96567 ],
#        [ 84.352745],
#        [ 52.642994],
#        [ 62.264244],
#        [ 71.923836],
#        [ 57.817757],
#        [ 68.91818 ],
#        [ 57.951103],
#        [ 52.351963],
#        [ 60.7826  ],
#        [ 79.02405 ],
#        [ 64.2642  ],
#        [ 53.61149 ],
#        [ 45.945   ],
#        [ 75.593155],
#        [ 78.33946 ],
#        [ 85.03764 ],
#        [ 32.661907],
#        [ 60.751377],
#        [ 57.250053],
#        [ 91.167786],
#        [ 50.19177 ],
#        [ 48.373184],
#        [ 40.337925],
#        [ 47.153294],
#        [ 53.515564],
#        [ 71.49466 ],
#        [ 75.79621 ],
#        [ 90.11922 ],
#        [ 78.81714 ],
#        [ 40.34118 ],
#        [ 82.72441 ],
#        [ 64.3558  ],
#        [ 57.81386 ],
#        [ 71.24938 ],
#        [ 78.76811 ],
#        [ 42.32915 ],
#        [ 53.0103  ],
#        [ 58.691715],
#        [ 47.045135],
#        [ 50.594475],
#        [ 46.67187 ],
#        [ 39.066143],
#        [ 77.60869 ],
#        [ 42.32869 ],
#        [ 52.98491 ],
#        [ 39.11188 ],
#        [ 95.765305],
#        [ 70.78529 ],
#        [ 62.538445],
#        [ 35.838142],
#        [ 85.20861 ],
#        [ 63.616997],
#        [ 47.500603],
#        [ 90.980995],
#        [ 33.15655 ],
#        [ 40.77768 ],
#        [ 45.757057],
#        [ 59.486767],
#        [ 53.078526],
#        [ 64.87383 ],
#        [ 53.119267],
#        [ 69.2134  ],
#        [ 76.5108  ],
#        [ 53.152424],
#        [ 78.377945],
#        [ 46.800896],
#        [ 66.6752  ],
#        [ 51.08063 ],
#        [ 54.483517],
#        [ 53.18341 ],
#        [ 53.022385],
#        [ 59.14484 ],
#        [ 50.704712],
#        [ 37.70301 ],
#        [ 48.2045  ],
#        [ 56.078873],
#        [ 53.46226 ],
#        [ 57.860172],
#        [ 61.982544],
#        [ 75.39527 ],
#        [ 72.746124],
#        [ 41.589813],
#        [ 81.421486],
#        [ 78.18005 ],
#        [ 62.352592],
#        [ 53.89636 ],
#        [ 71.81565 ],
#        [ 61.06678 ],
#        [ 73.811005],
#        [ 83.29885 ],
#        [ 43.61628 ],
#        [ 44.80957 ],
#        [ 71.04263 ],
#        [ 78.63563 ],
#        [ 72.160355],
#        [ 78.49199 ],
#        [ 67.580505],
#        [ 85.53107 ],
#        [ 58.145634],
#        [ 53.1586  ],
#        [ 47.460762],
#        [ 78.62453 ],
#        [ 48.341198],
#        [ 53.9484  ],
#        [ 46.74583 ],
#        [ 70.4848  ],
#        [ 46.2604  ],
#        [ 35.677193],
#        [ 70.183464],
#        [ 71.4168  ],
#        [ 85.504005]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import seaborn as sns




plt.figure(figsize=(8, 4))
sns.histplot(samples_spline["H0"][-1], fill=True, color="skyblue", label="Posterior H₀")
#sns.kdeplot(samples_spline["Omega_m"][1], fill=True, color="skyblue", label="Posterior H₀")
#sns.kdeplot(samples_spline["n_s"][1], fill=True, color="skyblue", label="Posterior H₀")
plt.title("Posterior Density for $H_0$ (Test Case 0)")
plt.xlabel("$H_0$")
plt.ylabel("Density")
plt.grid(True)
plt.legend()
plt.show()

# %%
#str(test_data)

# %%
figures_spline = workflow_spline.plot_default_diagnostics(
    test_data=test_data,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# # 3) Flow matching

# %%
inference_network_flow = bf.networks.FlowMatching()

# %%
workflow_flow = bf.BasicWorkflow(
     inference_network=inference_network_flow,
     summary_network=summary_network,
     adapter=adapter,
     simulator=simulator
)

# %%
history_spline = workflow_spline.fit_offline(
    data = training_data,
    epochs=20,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
)
