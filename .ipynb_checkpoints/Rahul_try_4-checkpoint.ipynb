# %% [markdown]
# # Imports

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower
import bayesflow as bf

import seaborn as sns
import time
import pickle
import tensorflow as tf


from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

print('Using CAMB %s installed at %s' % (camb.__version__, os.path.dirname(camb.__file__)))
# make sure the version and path is what you expect
# Out:
# Using CAMB 1.6.1 installed at C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\camb

# %% [markdown]
# # Data generating process

# %% [markdown]
# ## Definitions

# %%
def generate_logPK(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None):
    """
    Generate noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-3 to ~3.16
        noise_level (float): relative Gaussian noise (e.g., 0.05 = 5%)

    Returns:
        noisy_P_k (np.array): noisy matter power spectrum at redshift z=0
    """
    # Default k range: safe values for CAMB
    if k_vals is None:
        k_vals = np.logspace(-4, 1, 1024)


    ## To calculate the physical densities from the densities 
    # Baryon density
    Omega_b = 0.05
    
    # Cold dark matter density
    Omega_c = Omega_m - Omega_b

    # dimensionless Hubble parameter
    h = H0 / 100

    
    # physical densities
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2


    # Setup CAMB
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    # Run CAMB and get P(k)
    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

     # Conditional RNG
    if seed is not None:
        rng = np.random.default_rng(seed)  # reproducible
    else:
        rng = np.random.default_rng()      # fresh random

    # Add heteroscedastic Gaussian noise.
    # Noise is added according to the scale of P_k which make more realistic observations
    # noise = rng.normal(0, noise_level * P_k)
    # P_k_noisy = P_k + noise

    # Step 2: Apply log10 to each output
    log_k = np.log10(k_vals)
    #log_P_k_noisy = np.log10(P_k_noisy)
    
    
    
    
    log_P_k_clean = np.log10(P_k)

    log_noise = rng.normal(0, noise_level, len(P_k))
    log_P_k_noisy = log_P_k_clean + log_noise
    
    # shape adjustments
    log_k = log_k.reshape(-1, 1)
    log_P_k_clean = log_P_k_clean.reshape(-1, 1)
    log_P_k_noisy = log_P_k_noisy.reshape(-1, 1)

    return {     
        'log_k': log_k,
        'log_P_k_noisy': log_P_k_noisy,
        'log_P_k_clean': log_P_k_clean  
    }

# %% [markdown]
# ## Generating noisy observations
#
# $\theta^*$, True parameter from Planck 2018

# %%
# Define the true cosmological parameters
theta_star = {
    'H0': 67.4,
    'Omega_m': 0.315,
    'n_s': 0.965
}

# %%
# Generate the noisy power spectrum using theta_star
Log_Pk_obs = generate_logPK(
    H0=theta_star['H0'],
    Omega_m=theta_star['Omega_m'],
    n_s=theta_star['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    seed=42            # Optional, for reproducibility
)

# %% [markdown]
# ## Visualization
#
# P(k) vs k_vals

# %%
plt.plot(Log_Pk_obs['log_k'], Log_Pk_obs['log_P_k_clean'], label='Clean')
plt.plot(Log_Pk_obs['log_k'], Log_Pk_obs['log_P_k_noisy'], label='Noisy', alpha=0.6)
plt.xlabel(r'$\log_{10}(k)\ [h/\mathrm{Mpc}]$')
plt.ylabel(r'$\log_{10}(P(k))\ [(\mathrm{Mpc}/h)^3]$')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# $f(P\_k))$, probability density of power spectrum

# %%
# Plot histogram and KDE
plt.figure(figsize=(8, 5))
sns.histplot(Log_Pk_obs['log_P_k_noisy'], bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $\log_{10} P(k)$ Values')
plt.xlabel(r'$\log_{10} P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bayes Flow

# %% [markdown]
# Prior: $(\theta^{(s)}) \sim P(\theta)$

# %%
def prior(seed=None):
    rng = np.random.default_rng(seed)

    H0 = rng.uniform(30, 100)
    Omega_m = rng.uniform(0.1, 0.6)
    n_s = rng.uniform(0.8, 1.5)

    return {
        'H0': H0,
        'Omega_m': Omega_m,
        'n_s': n_s
    }

# %% [markdown]
# # Prior Plots

# %%
# Parameter ranges
H0_range = (30, 100)
Om_range = (0.1, 0.6)
ns_range = (0.8, 1.5)

# Define x values
x_H0 = np.linspace(20, 110, 1000)
x_Om = np.linspace(0, 0.7, 1000)
x_ns = np.linspace(0.7, 1.6, 1000)

# Uniform densities
def uniform_density(x, a, b):
    return np.where((x >= a) & (x <= b), 1 / (b - a), 0)

# Compute densities
y_H0 = uniform_density(x_H0, *H0_range)
y_Om = uniform_density(x_Om, *Om_range)
y_ns = uniform_density(x_ns, *ns_range)

# Plotting
plt.figure(figsize=(15, 4))

# H0
plt.subplot(1, 3, 1)
plt.plot(x_H0, y_H0, lw=2)
plt.fill_between(x_H0, 0, y_H0, alpha=0.3)
plt.title('Uniform Prior: H₀ ∈ [30, 100]')
plt.xlabel('H₀')
plt.ylabel('Density')

# Ωm
plt.subplot(1, 3, 2)
plt.plot(x_Om, y_Om, lw=2)
plt.fill_between(x_Om, 0, y_Om, alpha=0.3)
plt.title('Uniform Prior: Ωₘ ∈ [0.1, 0.6]')
plt.xlabel('Ωₘ')
plt.ylabel('Density')

# ns
plt.subplot(1, 3, 3)
plt.plot(x_ns, y_ns, lw=2)
plt.fill_between(x_ns, 0, y_ns, alpha=0.3)
plt.title('Uniform Prior: nₛ ∈ [0.8, 1.5]')
plt.xlabel('nₛ')
plt.ylabel('Density')
plt.tight_layout()

# Save as high-resolution PNG
plt.savefig("uniform_priors.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Uniform density function
def uniform_density(x, a, b):
    return np.where((x >= a) & (x <= b), 1 / (b - a), 0)

# Plot 1: Hubble constant H0
x_H0 = np.linspace(20, 110, 1000)
y_H0 = uniform_density(x_H0, 30, 100)

plt.figure(figsize=(6, 4))
plt.plot(x_H0, y_H0, lw=2)
plt.fill_between(x_H0, 0, y_H0, alpha=0.3)
plt.title('Uniform Prior Density: H₀ ∈ [30, 100]')
plt.xlabel('H₀')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Plot 2: Matter density Ωm
x_Om = np.linspace(0, 0.7, 1000)
y_Om = uniform_density(x_Om, 0.1, 0.6)

plt.figure(figsize=(6, 4))
plt.plot(x_Om, y_Om, lw=2)
plt.fill_between(x_Om, 0, y_Om, alpha=0.3)
plt.title('Uniform Prior Density: Ωₘ ∈ [0.1, 0.6]')
plt.xlabel('Ωₘ')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Plot 3: Spectral index ns
x_ns = np.linspace(0.7, 1.6, 1000)
y_ns = uniform_density(x_ns, 0.8, 1.5)

plt.figure(figsize=(6, 4))
plt.plot(x_ns, y_ns, lw=2)
plt.fill_between(x_ns, 0, y_ns, alpha=0.3)
plt.title('Uniform Prior Density: nₛ ∈ [0.8, 1.5]')
plt.xlabel('nₛ')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# Likelihood: $(y^{(s)}) \sim P(y | \theta)$
# The same function but with just one output of length of k_vals

# %%
def likelihood(H0, Omega_m, n_s, k_vals=None, noise_level=0.2, seed=None, n = 256):
    """
    Generate log10 of the noisy matter power spectrum P(k) from given cosmological parameters.

    Parameters:
        H0 (float): Hubble constant (km/s/Mpc)
        Omega_m (float): total matter density (Ω_m)
        n_s (float): spectral index
        k_vals (np.array or None): k values (1/Mpc). Default: logspace from 1e-4 to 10
        noise_level (float): standard deviation of additive Gaussian noise in log space
        seed (int or None): for reproducibility

    Returns:
        log_P_k_noisy (np.array): noisy log10 power spectrum at z = 0
    """

    if k_vals is None:
        k_vals = np.logspace(-4, 1, n)

    Omega_b = 0.05
    Omega_c = Omega_m - Omega_b
    h = H0 / 100
    ombh2 = Omega_b * h**2
    omch2 = Omega_c * h**2

    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2)
    pars.InitPower.set_params(ns=n_s)
    pars.set_matter_power(redshifts=[0], kmax=max(k_vals))

    PK = camb.get_matter_power_interpolator(pars, nonlinear=False, kmax=max(k_vals))
    P_k = PK.P(0, k_vals)

    if seed is not None:
        rng = np.random.default_rng(seed)
    else:
        rng = np.random.default_rng()

    log_k = np.log10(k_vals)
    log_P_k_clean = np.log10(P_k)
    log_noise = rng.normal(0, noise_level, len(P_k))
    log_P_k_noisy = log_P_k_clean + log_noise


    # shape adjustments
    log_k = log_k.reshape(-1, 1)
    log_P_k_clean = log_P_k_clean.reshape(-1, 1)
    log_P_k_noisy = log_P_k_noisy.reshape(-1, 1)

    return {
        'log_P_k_noisy': log_P_k_noisy
    }

# %% [markdown]
# ### Testing Prior and Likelihood

# %%
theta_test = prior()
print(theta_test)
# Out:
# {'H0': 31.379466689070917, 'Omega_m': 0.5404443094920842, 'n_s': 1.170675307278903}

# %%
# Generate the noisy power spectrum using theta_star
Log_Pk_test = likelihood(
    H0=theta_test['H0'],
    Omega_m=theta_test['Omega_m'],
    n_s=theta_test['n_s'],
    noise_level=0.2,   # 20% relative Gaussian noise
    n = 512
)

# %%
Log_Pk_test.keys()
# Out:
# dict_keys(['log_P_k_noisy'])

# %%
Log_Pk_test['log_P_k_noisy'].shape
# Out:
# (512, 1)

# %%
# Plot histogram and KDE for log10(P(k))
plt.figure(figsize=(8, 5))
sns.histplot(Log_Pk_test['log_P_k_noisy'].flatten(), bins=50, kde=True, stat="density", color='skyblue', edgecolor='black')

plt.title('Histogram and KDE of Noisy $\log_{10} P(k)$ Values')
plt.xlabel(r'$\log_{10} P(k)$')
plt.ylabel('Density')
plt.grid(True)
plt.tight_layout()

plt.savefig("hist_kde_y.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # --------------------------  Bayes Flow  --------------------------------------

# %% [markdown]
# ### Sample from the Joint Distribution $(\theta^{(s)}, y^{(s)}) \sim P(\theta, y)$

# %% [markdown]
# ### Simulator

# %%
simulator = bf.make_simulator([prior, likelihood])

# %% [markdown]
# ###  Adapter

# %%
adapter_std = (
    bf.Adapter()
    .concatenate(["H0", "Omega_m", "n_s"], into="inference_variables")
    .rename("log_P_k_noisy", "summary_variables")
)

# %% [markdown]
# ### Summary Networks

# %%
class CNNSummaryNet(tf.keras.Model):
    def __init__(self, latent_dim=64):
        super().__init__()
        self.latent_dim = latent_dim

        ## Layer 1 
        # 32 filters, kernel 3, activation ReLu
        self.conv1 = tf.keras.layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')
        self.pool1 = tf.keras.layers.MaxPooling1D(pool_size=2)

        ## Layer 2
        self.conv2 = tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', padding='same')
        self.pool2 = tf.keras.layers.MaxPooling1D(pool_size=2)

        ## Layer 3
        self.conv3 = tf.keras.layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')
        self.global_pool = tf.keras.layers.GlobalAveragePooling1D()
        
        ### Outer layer
        self.dense = tf.keras.layers.Dense(latent_dim, activation='relu')

    def build(self, input_shape):
        
        # Build layers dynamically (important for BayesFlow)
        dummy_input = tf.zeros(input_shape)
        self.call(dummy_input)
        super().build(input_shape)

    def call(self, x):
        
        x = self.conv1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.global_pool(x)
        return self.dense(x)

    def compute_metrics(self, summary_variables, stage=None):
        outputs = self(summary_variables)
        return {"outputs": outputs}

    def compute_output_shape(self, input_shape):
        
        # Ensure input_shape is a tuple like (batch_size, sequence_length, channels)
        batch_size = input_shape[0] if isinstance(input_shape, tuple) else None
        return (batch_size, self.latent_dim)

# 4) CNN
summary_network_CNN = CNNSummaryNet(latent_dim=32)

# %% [markdown]
# ## Datasets : Training, Validation, Test

# %%
# Training data
with open("training_data.pkl", "rb") as f:
    training_data = pickle.load(f)

print(training_data.keys())  # Should match original keys
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %%
# Validation data
with open("validation_data.pkl", "rb") as f:
    validation_data = pickle.load(f)

print(validation_data.keys())
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %%
# Test data
with open("test_data.pkl", "rb") as f:
    test_data = pickle.load(f)

print(test_data.keys())
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %%
# Load test data
with open("test_data.pkl", "rb") as f:
    test_data = pickle.load(f)

print(test_data.keys())
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %% [markdown]
# ### 4) Affine + CNN

# %%
inference_network_affine = bf.networks.CouplingFlow(
    num_params=3,
    num_coupling_layers=12,        # more than default
    conditions_dim=3,              # <<< IMPORTANT
    transform="affine",            # affine coupling
    use_actnorm=True,              # better conditioning
    permutation="shuffle",         # random perm between layers
)

# %%
workflow_affine_CNN = bf.BasicWorkflow(
    inference_network=inference_network_affine,
    summary_network=summary_network_CNN,
    adapter=adapter_std,
    simulator=simulator,
    standardize={"summary_variables": True, "inference_variables": True}
)

# %%
# Define EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=20,           # Stop if no improvement after 20 epochs
    restore_best_weights=True # Roll back to the best weights
)

# %%
history_affine_CNN = workflow_affine_CNN.fit_offline(
    data = training_data,
    epochs=200,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
    #callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 37s 57ms/step - loss: 4.2540 - val_loss: 4.2855
# Epoch 2/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.2531 - val_loss: 4.2602
# Epoch 3/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.9701 - val_loss: 3.6502
# Epoch 4/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 3.4943 - val_loss: 2.8945
# Epoch 5/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.4337 - val_loss: 2.0907
# Epoch 6/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.1228 - val_loss: 1.9636
# Epoch 7/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.0105 - val_loss: 2.2850
# Epoch 8/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.9721 - val_loss: 1.8518
# Epoch 9/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.9482 - val_loss: 1.8453
# Epoch 10/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.9482 - val_loss: 2.1152
# Epoch 11/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.9001 - val_loss: 1.6428
# Epoch 12/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.7920 - val_loss: 1.7242
# Epoch 13/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.5738 - val_loss: 1.6454
# Epoch 14/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.2186 - val_loss: 0.8249
# Epoch 15/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.8396 - val_loss: 0.6364
# Epoch 16/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4765 - val_loss: 0.4234
# Epoch 17/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1448 - val_loss: -0.3576
# Epoch 18/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -0.3483 - val_loss: -0.6032
# Epoch 19/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -0.4588 - val_loss: -0.2983
# Epoch 20/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -0.3786 - val_loss: -0.7192
# Epoch 21/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -0.4884 - val_loss: -0.2517
# Epoch 22/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -0.6216 - val_loss: -0.8016
# Epoch 23/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: -0.8452 - val_loss: -0.6826
# Epoch 24/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -0.6926 - val_loss: -0.9602
# Epoch 25/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -0.7028 - val_loss: -1.0488
# Epoch 26/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -0.7770 - val_loss: -1.1070
# Epoch 27/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -0.7650 - val_loss: -0.6808
# Epoch 28/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: -0.8057 - val_loss: -1.1205
# Epoch 29/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -0.9920 - val_loss: 0.7109
# Epoch 30/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -0.7997 - val_loss: -0.9467
# Epoch 31/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.0580 - val_loss: -1.2075
# Epoch 32/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -0.9685 - val_loss: -1.2472
# Epoch 33/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: -0.9392 - val_loss: -1.2554
# Epoch 34/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -0.9829 - val_loss: -0.7536
# Epoch 35/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -1.2014 - val_loss: -1.1288
# Epoch 36/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.1275 - val_loss: -1.2110
# Epoch 37/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.1961 - val_loss: -1.2135
# Epoch 38/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.1323 - val_loss: -0.9462
# Epoch 39/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.0439 - val_loss: -1.0531
# Epoch 40/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.2470 - val_loss: -0.6452
# Epoch 41/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.2325 - val_loss: -1.0756
# Epoch 42/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.0621 - val_loss: -1.3209
# Epoch 43/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.2086 - val_loss: -0.8342
# Epoch 44/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.1523 - val_loss: -1.4725
# Epoch 45/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -1.1324 - val_loss: -0.7707
# Epoch 46/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.1954 - val_loss: -1.3518
# Epoch 47/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.3130 - val_loss: -1.1600
# Epoch 48/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.3730 - val_loss: -1.3826
# Epoch 49/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -1.2930 - val_loss: -1.0421
# Epoch 50/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -1.0738 - val_loss: -1.2592
# Epoch 51/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.2881 - val_loss: -1.5748
# Epoch 52/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.3791 - val_loss: -1.4164
# Epoch 53/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: -1.3484 - val_loss: -1.3737
# Epoch 54/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: -1.3321 - val_loss: -1.4488
# Epoch 55/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: -1.4679 - val_loss: -1.5921
# Epoch 56/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.3982 - val_loss: -1.3752
# Epoch 57/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: -1.4377 - val_loss: -1.2814
# Epoch 58/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -1.4013 - val_loss: -1.6225
# Epoch 59/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: -1.2292 - val_loss: -1.2108
# Epoch 60/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: -1.2477 - val_loss: -1.5784
# Epoch 61/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -1.4364 - val_loss: -1.3152
# Epoch 62/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.4460 - val_loss: -1.6288
# Epoch 63/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.4797 - val_loss: -1.4418
# Epoch 64/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.2612 - val_loss: -1.1534
# Epoch 65/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4157 - val_loss: -1.6231
# Epoch 66/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.3098 - val_loss: -0.6843
# Epoch 67/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.4377 - val_loss: -1.6750
# Epoch 68/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.4114 - val_loss: -1.6927
# Epoch 69/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -1.4849 - val_loss: -1.5600
# Epoch 70/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4956 - val_loss: -1.5999
# Epoch 71/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.5417 - val_loss: -1.1427
# Epoch 72/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.3483 - val_loss: -1.5658
# Epoch 73/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4657 - val_loss: -1.0839
# Epoch 74/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.3480 - val_loss: -1.4822
# Epoch 75/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.4131 - val_loss: -1.6955
# Epoch 76/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.5055 - val_loss: -1.3387
# Epoch 77/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4409 - val_loss: -1.3562
# Epoch 78/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5551 - val_loss: -1.5969
# Epoch 79/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4987 - val_loss: -1.6951
# Epoch 80/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.5543 - val_loss: -1.4331
# Epoch 81/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.4373 - val_loss: -1.7200
# Epoch 82/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5173 - val_loss: -1.6589
# Epoch 83/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5393 - val_loss: -1.6327
# Epoch 84/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4776 - val_loss: -1.5820
# Epoch 85/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.5751 - val_loss: -1.7393
# Epoch 86/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.4980 - val_loss: -1.7365
# Epoch 87/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5474 - val_loss: -1.7376
# Epoch 88/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.5487 - val_loss: -1.6717
# Epoch 89/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5186 - val_loss: -1.0858
# Epoch 90/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.4762 - val_loss: -1.6979
# Epoch 91/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5850 - val_loss: -1.7345
# Epoch 92/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.6946 - val_loss: -1.6414
# Epoch 93/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5630 - val_loss: -1.6421
# Epoch 94/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.6268 - val_loss: -1.7762
# Epoch 95/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.6492 - val_loss: -1.7333
# Epoch 96/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.5933 - val_loss: -1.5495
# Epoch 97/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.6407 - val_loss: -1.5183
# Epoch 98/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.6712 - val_loss: -1.7024
# Epoch 99/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.7342 - val_loss: -1.2944
# Epoch 100/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.6334 - val_loss: -1.8007
# Epoch 101/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: -1.7292 - val_loss: -1.6409
# Epoch 102/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.6531 - val_loss: -1.6979
# Epoch 103/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.6756 - val_loss: -1.8098
# Epoch 104/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.7110 - val_loss: -1.8380
# Epoch 105/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.7879 - val_loss: -1.7479
# Epoch 106/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.7162 - val_loss: -1.8892
# Epoch 107/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.7040 - val_loss: -1.7687
# Epoch 108/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.7506 - val_loss: -1.7792
# Epoch 109/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.7409 - val_loss: -1.6218
# Epoch 110/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -1.6890 - val_loss: -1.8679
# Epoch 111/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.7541 - val_loss: -1.8358
# Epoch 112/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.7770 - val_loss: -1.8615
# Epoch 113/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.8137 - val_loss: -1.7432
# Epoch 114/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.8049 - val_loss: -1.7870
# Epoch 115/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -1.7853 - val_loss: -1.7298
# Epoch 116/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.8018 - val_loss: -1.8521
# Epoch 117/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.7758 - val_loss: -1.7596
# Epoch 118/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.8112 - val_loss: -1.8212
# Epoch 119/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -1.8372 - val_loss: -1.8991
# Epoch 120/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.8335 - val_loss: -1.8665
# Epoch 121/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.8396 - val_loss: -1.9116
# Epoch 122/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.7759 - val_loss: -1.6282
# Epoch 123/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.8006 - val_loss: -1.8009
# Epoch 124/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.8398 - val_loss: -1.9072
# Epoch 125/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.8158 - val_loss: -1.8969
# Epoch 126/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -1.7952 - val_loss: -1.9445
# Epoch 127/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.8851 - val_loss: -1.7578
# Epoch 128/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.8799 - val_loss: -1.8470
# Epoch 129/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: -1.8740 - val_loss: -1.9498
# Epoch 130/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.8772 - val_loss: -1.9243
# Epoch 131/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.8558 - val_loss: -1.9346
# Epoch 132/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.8680 - val_loss: -1.9680
# Epoch 133/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -1.8672 - val_loss: -1.8236
# Epoch 134/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.9104 - val_loss: -1.9643
# Epoch 135/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.9171 - val_loss: -1.9324
# Epoch 136/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.9061 - val_loss: -1.8835
# Epoch 137/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.8936 - val_loss: -1.9568
# Epoch 138/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.9027 - val_loss: -1.9620
# Epoch 139/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.9241 - val_loss: -1.9207
# Epoch 140/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.9390 - val_loss: -1.9596
# Epoch 141/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: -1.9398 - val_loss: -1.9652
# Epoch 142/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9259 - val_loss: -1.9587
# Epoch 143/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9123 - val_loss: -1.9843
# Epoch 144/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9551 - val_loss: -1.9171
# Epoch 145/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9425 - val_loss: -1.8893
# Epoch 146/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9434 - val_loss: -1.9808
# Epoch 147/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9644 - val_loss: -1.9560
# Epoch 148/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9552 - val_loss: -2.0032
# Epoch 149/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -1.9762 - val_loss: -2.0092
# Epoch 150/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9636 - val_loss: -2.0103
# Epoch 151/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9695 - val_loss: -2.0159
# Epoch 152/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9665 - val_loss: -1.9606
# Epoch 153/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9833 - val_loss: -2.0351
# Epoch 154/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9759 - val_loss: -1.9357
# Epoch 155/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -1.9678 - val_loss: -1.5960
# Epoch 156/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9599 - val_loss: -1.9888
# Epoch 157/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9849 - val_loss: -1.9846
# Epoch 158/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9943 - val_loss: -1.9815
# Epoch 159/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -1.9987 - val_loss: -2.0054
# Epoch 160/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9977 - val_loss: -1.9994
# Epoch 161/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9927 - val_loss: -2.0283
# Epoch 162/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0004 - val_loss: -2.0333
# Epoch 163/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -1.9940 - val_loss: -2.0425
# Epoch 164/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: -2.0094 - val_loss: -2.0099
# Epoch 165/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0075 - val_loss: -1.9471
# Epoch 166/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -1.9993 - val_loss: -2.0361
# Epoch 167/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0111 - val_loss: -2.0077
# Epoch 168/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -2.0151 - val_loss: -2.0428
# Epoch 169/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0161 - val_loss: -2.0448
# Epoch 170/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0225 - val_loss: -2.0196
# Epoch 171/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0223 - val_loss: -2.0138
# Epoch 172/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0064 - val_loss: -2.0197
# Epoch 173/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -2.0234 - val_loss: -2.0405
# Epoch 174/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0239 - val_loss: -2.0495
# Epoch 175/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0248 - val_loss: -2.0432
# Epoch 176/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0210 - val_loss: -2.0465
# Epoch 177/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0306 - val_loss: -2.0287
# Epoch 178/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -2.0302 - val_loss: -2.0417
# Epoch 179/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0315 - val_loss: -2.0459
# Epoch 180/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0334 - val_loss: -2.0373
# Epoch 181/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0305 - val_loss: -2.0426
# Epoch 182/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0376 - val_loss: -2.0566
# Epoch 183/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -2.0354 - val_loss: -2.0546
# Epoch 184/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: -2.0391 - val_loss: -2.0445
# Epoch 185/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0394 - val_loss: -2.0527
# Epoch 186/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -2.0404 - val_loss: -2.0627
# Epoch 187/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0416 - val_loss: -2.0578
# Epoch 188/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0419 - val_loss: -2.0513
# Epoch 189/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0421 - val_loss: -2.0577
# Epoch 190/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -2.0441 - val_loss: -2.0567
# Epoch 191/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0442 - val_loss: -2.0524
# Epoch 192/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0456 - val_loss: -2.0572
# Epoch 193/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: -2.0463 - val_loss: -2.0490
# Epoch 194/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -2.0469 - val_loss: -2.0583
# Epoch 195/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: -2.0477 - val_loss: -2.0576
# Epoch 196/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: -2.0477 - val_loss: -2.0582
# Epoch 197/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: -2.0482 - val_loss: -2.0573
# Epoch 198/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -2.0482 - val_loss: -2.0583
# Epoch 199/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: -2.0486 - val_loss: -2.0585
# Epoch 200/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: -2.0487 - val_loss: -2.0584

# %%
figures_affine_CNN = workflow_affine_CNN.plot_default_diagnostics(
    test_data=test_data,
    calibration_histogram={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12} ,
    
)

# %%
workflow_affine_CNN.plot_custom_diagnostics(
    test_data=test_data,   # <-- your simulated dataset of size 1000
    plot_fns={
        "calibration_histogram":bf.diagnostics.plots.calibration_histogram
    },
)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 1. Confidence intervals might be unreliable!
# {'calibration_histogram': <Figure size 1500x500 with 3 Axes>}

# %% [markdown]
# # Save each figure from the affine CNN diagnostics
# for name, fig in figures_affine_CNN.items():
#     fig.savefig(f"{name}_affine_CNN.png", dpi=300, bbox_inches="tight")
#     fig.savefig(f"{name}_affine_CNN.pdf", bbox_inches="tight")  # optional vector format

# %%
bf.diagnostics.plots.pairs_posterior(
    test_data, variable_keys=['H0', 'Omega_m', 'n_s']
)

# %% [markdown]
# # Spline + CNN - Coupling Inference Networks

# %% [markdown]
# ### Spline + CNN

# %%
# More expressive Affine Coupling Flow
inference_network_spline = bf.networks.CouplingFlow(
    num_coupling_layers=12,             # Go deeper (more transformations)
    transform="spline",           # Stick to spline (more flexible than affine)
    transform_net_units=[128, 128, 128]
)

# %%
# Define EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=20,           # Stop if no improvement after 20 epochs
    restore_best_weights=True # Roll back to the best weights
)

# %%
workflow_spline_CNN = bf.BasicWorkflow(
     inference_network=inference_network_spline,
     summary_network=summary_network_CNN,
     adapter=adapter_std,
     simulator=simulator,
    standardize={"summary_variables": True, "inference_variables": True}
)

# %%
history_spline_CNN = workflow_spline_CNN.fit_offline(
    data = training_data,
    epochs=200,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data
    #callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 110s 205ms/step - loss: 3.8446 - val_loss: 3.0631
# Epoch 2/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.7706 - val_loss: 0.7371
# Epoch 3/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.4873 - val_loss: 0.1825
# Epoch 4/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.1232 - val_loss: 0.2603
# Epoch 5/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.1411 - val_loss: 0.1173
# Epoch 6/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -0.1902 - val_loss: -0.4872
# Epoch 7/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: -0.5079 - val_loss: -0.3762
# Epoch 8/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -0.5961 - val_loss: -0.1444
# Epoch 9/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.6646 - val_loss: 0.8277
# Epoch 10/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.5726 - val_loss: -1.1580
# Epoch 11/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.8306 - val_loss: -1.0406
# Epoch 12/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.9624 - val_loss: -0.0900
# Epoch 13/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.4685 - val_loss: -0.7752
# Epoch 14/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: -0.8542 - val_loss: -0.8288
# Epoch 15/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.9684 - val_loss: -0.8030
# Epoch 16/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.8916 - val_loss: -0.3151
# Epoch 17/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -0.7204 - val_loss: -0.8975
# Epoch 18/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.8278 - val_loss: -0.7173
# Epoch 19/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.7726 - val_loss: -1.3794
# Epoch 20/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.0520 - val_loss: -1.4084
# Epoch 21/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.1918 - val_loss: -1.3660
# Epoch 22/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.1213 - val_loss: -1.2464
# Epoch 23/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -1.1545 - val_loss: -1.2017
# Epoch 24/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.2741 - val_loss: -1.5225
# Epoch 25/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.1496 - val_loss: -1.4074
# Epoch 26/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.8474 - val_loss: -0.7654
# Epoch 27/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: -0.9591 - val_loss: -0.7094
# Epoch 28/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: -0.7426 - val_loss: -0.2266
# Epoch 29/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.7171 - val_loss: -0.7178
# Epoch 30/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.4888 - val_loss: -1.2659
# Epoch 31/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: -0.8112 - val_loss: -1.1858
# Epoch 32/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.6712 - val_loss: -0.2754
# Epoch 33/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.6082 - val_loss: -1.0287
# Epoch 34/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -0.7873 - val_loss: -0.6721
# Epoch 35/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.8075 - val_loss: -0.6703
# Epoch 36/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.7765 - val_loss: -1.1737
# Epoch 37/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.8496 - val_loss: -1.2994
# Epoch 38/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.6170 - val_loss: -0.3879
# Epoch 39/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.3608 - val_loss: -0.1357
# Epoch 40/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.5280 - val_loss: -0.8129
# Epoch 41/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.4815 - val_loss: -0.1998
# Epoch 42/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.4834 - val_loss: -0.4121
# Epoch 43/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: -0.6267 - val_loss: -1.1939
# Epoch 44/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.7582 - val_loss: -0.6163
# Epoch 45/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.8157 - val_loss: -1.4307
# Epoch 46/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.7513 - val_loss: -0.2630
# Epoch 47/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.6379 - val_loss: -0.6951
# Epoch 48/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.8139 - val_loss: -1.2141
# Epoch 49/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -0.5108 - val_loss: -1.0480
# Epoch 50/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: -0.7463 - val_loss: -1.0309
# Epoch 51/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.2258 - val_loss: -0.9078
# Epoch 52/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.3505 - val_loss: -0.8077
# Epoch 53/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.6629 - val_loss: -0.1063
# Epoch 54/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.6918 - val_loss: -1.1841
# Epoch 55/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.8092 - val_loss: -0.9140
# Epoch 56/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -0.3631 - val_loss: -0.6425
# Epoch 57/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.7843 - val_loss: -0.8439
# Epoch 58/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: -0.7593 - val_loss: 0.1907
# Epoch 59/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -0.7897 - val_loss: -0.4508
# Epoch 60/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.8507 - val_loss: -1.0517
# Epoch 61/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -0.8583 - val_loss: -1.1840
# Epoch 62/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -1.0096 - val_loss: -1.0633
# Epoch 63/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.9201 - val_loss: -1.1915
# Epoch 64/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.7545 - val_loss: -1.1142
# Epoch 65/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.0810 - val_loss: -1.5022
# Epoch 66/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.1770 - val_loss: -1.1597
# Epoch 67/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -0.9921 - val_loss: -1.0870
# Epoch 68/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -0.8288 - val_loss: -0.6130
# Epoch 69/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: -0.9206 - val_loss: -1.1662
# Epoch 70/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.0677 - val_loss: -1.4031
# Epoch 71/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.1689 - val_loss: -1.3250
# Epoch 72/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.2544 - val_loss: -1.1636
# Epoch 73/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.3280 - val_loss: -1.2833
# Epoch 74/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.1745 - val_loss: -0.9864
# Epoch 75/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.8876 - val_loss: -1.0891
# Epoch 76/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.0586 - val_loss: -1.3770
# Epoch 77/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.1800 - val_loss: -0.7795
# Epoch 78/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -0.9143 - val_loss: -1.4407
# Epoch 79/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.2321 - val_loss: -1.4161
# Epoch 80/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.2926 - val_loss: -1.2507
# Epoch 81/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -0.9368 - val_loss: -1.3821
# Epoch 82/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -1.2709 - val_loss: -1.4480
# Epoch 83/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.1705 - val_loss: -0.7837
# Epoch 84/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -0.8433 - val_loss: -1.5479
# Epoch 85/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.3703 - val_loss: -0.9893
# Epoch 86/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.3165 - val_loss: -1.4090
# Epoch 87/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.1653 - val_loss: -0.0837
# Epoch 88/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.1169 - val_loss: -1.3643
# Epoch 89/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.3337 - val_loss: -1.5599
# Epoch 90/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.1877 - val_loss: -1.1264
# Epoch 91/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.2428 - val_loss: -1.0020
# Epoch 92/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.1223 - val_loss: -1.6703
# Epoch 93/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -0.9816 - val_loss: -0.8776
# Epoch 94/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.2110 - val_loss: -1.5443
# Epoch 95/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.2571 - val_loss: -1.4277
# Epoch 96/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.4106 - val_loss: -0.2167
# Epoch 97/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.2227 - val_loss: -0.7753
# Epoch 98/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.3654 - val_loss: -1.2030
# Epoch 99/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.6257 - val_loss: -1.8596
# Epoch 100/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -1.4949 - val_loss: -1.2518
# Epoch 101/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.4858 - val_loss: -1.3740
# Epoch 102/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.5776 - val_loss: -1.7974
# Epoch 103/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.5947 - val_loss: -0.8838
# Epoch 104/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.8006 - val_loss: -1.8314
# Epoch 105/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.7226 - val_loss: -1.9035
# Epoch 106/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.6706 - val_loss: -1.7668
# Epoch 107/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -1.4423 - val_loss: -2.0322
# Epoch 108/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: -1.6917 - val_loss: -2.0556
# Epoch 109/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.6336 - val_loss: -1.5591
# Epoch 110/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.7009 - val_loss: -1.8112
# Epoch 111/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.7397 - val_loss: -1.8845
# Epoch 112/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.6216 - val_loss: -1.9356
# Epoch 113/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.8509 - val_loss: -1.8653
# Epoch 114/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.7359 - val_loss: -2.0220
# Epoch 115/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.8541 - val_loss: -2.0027
# Epoch 116/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.8511 - val_loss: -1.6736
# Epoch 117/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.7815 - val_loss: -1.3648
# Epoch 118/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: -1.8663 - val_loss: -1.8575
# Epoch 119/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.9280 - val_loss: -2.0275
# Epoch 120/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.7124 - val_loss: -1.5683
# Epoch 121/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.8310 - val_loss: -2.1424
# Epoch 122/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.9416 - val_loss: -2.1386
# Epoch 123/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -1.9250 - val_loss: -2.0864
# Epoch 124/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -2.0240 - val_loss: -1.9222
# Epoch 125/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.0339 - val_loss: -1.9910
# Epoch 126/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: -1.8188 - val_loss: -2.1457
# Epoch 127/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.0206 - val_loss: -2.0806
# Epoch 128/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -2.1179 - val_loss: -2.2343
# Epoch 129/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.0307 - val_loss: -1.6277
# Epoch 130/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -1.9449 - val_loss: -1.5996
# Epoch 131/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -1.9849 - val_loss: -1.4310
# Epoch 132/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -2.0747 - val_loss: -2.3503
# Epoch 133/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.1283 - val_loss: -2.2372
# Epoch 134/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.1663 - val_loss: -2.2736
# Epoch 135/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -2.3091 - val_loss: -2.3896
# Epoch 136/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.2431 - val_loss: -2.3039
# Epoch 137/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.2879 - val_loss: -2.3363
# Epoch 138/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -2.3483 - val_loss: -2.4346
# Epoch 139/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.4323 - val_loss: -2.4218
# Epoch 140/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.3786 - val_loss: -2.2211
# Epoch 141/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -2.4106 - val_loss: -2.1561
# Epoch 142/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.4419 - val_loss: -2.5282
# Epoch 143/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.3788 - val_loss: -2.4865
# Epoch 144/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -2.4761 - val_loss: -2.0482
# Epoch 145/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -2.5169 - val_loss: -2.4278
# Epoch 146/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.5479 - val_loss: -2.4645
# Epoch 147/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.4884 - val_loss: -2.5880
# Epoch 148/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -2.5251 - val_loss: -2.5797
# Epoch 149/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.5748 - val_loss: -2.4966
# Epoch 150/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.5641 - val_loss: -2.4770
# Epoch 151/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: -2.6204 - val_loss: -2.5401
# Epoch 152/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.6411 - val_loss: -2.6181
# Epoch 153/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: -2.6208 - val_loss: -2.6724
# Epoch 154/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -2.6265 - val_loss: -2.4404
# Epoch 155/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: -2.6624 - val_loss: -2.7230
# Epoch 156/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: -2.6544 - val_loss: -2.6736
# Epoch 157/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: -2.6832 - val_loss: -2.6731
# Epoch 158/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.6742 - val_loss: -2.6378
# Epoch 159/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.5996 - val_loss: -2.4088
# Epoch 160/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.7073 - val_loss: -2.6724
# Epoch 161/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: -2.7170 - val_loss: -2.6744
# Epoch 162/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.6720 - val_loss: -2.7466
# Epoch 163/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.7180 - val_loss: -2.7791
# Epoch 164/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.7232 - val_loss: -2.5665
# Epoch 165/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.6925 - val_loss: -2.7041
# Epoch 166/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.7603 - val_loss: -2.6934
# Epoch 167/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -2.7508 - val_loss: -2.7522
# Epoch 168/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.7810 - val_loss: -2.7763
# Epoch 169/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.7912 - val_loss: -2.7306
# Epoch 170/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.7845 - val_loss: -2.7675
# Epoch 171/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.7975 - val_loss: -2.7394
# Epoch 172/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.7951 - val_loss: -2.7870
# Epoch 173/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8066 - val_loss: -2.6999
# Epoch 174/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -2.8096 - val_loss: -2.7629
# Epoch 175/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8083 - val_loss: -2.6871
# Epoch 176/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8236 - val_loss: -2.7820
# Epoch 177/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8143 - val_loss: -2.8453
# Epoch 178/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.8364 - val_loss: -2.8247
# Epoch 179/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8353 - val_loss: -2.7850
# Epoch 180/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -2.8291 - val_loss: -2.8310
# Epoch 181/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8526 - val_loss: -2.8458
# Epoch 182/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8428 - val_loss: -2.8410
# Epoch 183/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: -2.8536 - val_loss: -2.8445
# Epoch 184/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8693 - val_loss: -2.8385
# Epoch 185/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8533 - val_loss: -2.8238
# Epoch 186/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8685 - val_loss: -2.8442
# Epoch 187/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8711 - val_loss: -2.8271
# Epoch 188/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8761 - val_loss: -2.8537
# Epoch 189/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8793 - val_loss: -2.8478
# Epoch 190/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: -2.8818 - val_loss: -2.8535
# Epoch 191/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8797 - val_loss: -2.8393
# Epoch 192/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8766 - val_loss: -2.8589
# Epoch 193/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.8859 - val_loss: -2.8577
# Epoch 194/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.8882 - val_loss: -2.8609
# Epoch 195/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8899 - val_loss: -2.8513
# Epoch 196/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: -2.8896 - val_loss: -2.8571
# Epoch 197/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8897 - val_loss: -2.8553
# Epoch 198/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: -2.8922 - val_loss: -2.8584
# Epoch 199/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: -2.8927 - val_loss: -2.8579
# Epoch 200/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: -2.8930 - val_loss: -2.8579

# %%
figures_spline_CNN = workflow_spline_CNN.plot_default_diagnostics(
    test_data=test_data,
    rank_histogram_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}  
)

# %%
workflow_spline_CNN.plot_custom_diagnostics(
    test_data=test_data,   # <-- your simulated dataset of size 1000
    plot_fns={
        "calibration_histogram":bf.diagnostics.plots.calibration_histogram
    },
)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 1. Confidence intervals might be unreliable!
# {'calibration_histogram': <Figure size 1500x500 with 3 Axes>}

# %% [markdown]
# # Save each figure from the spline CNN diagnostics
# for name, fig in figures_spline_CNN.items():
#     fig.savefig(f"{name}_spline_CNN.png", dpi=300, bbox_inches="tight")
#     fig.savefig(f"{name}_spline_CNN.pdf", bbox_inches="tight")  # optional vector version

# %%
test_data.keys()
# Out:
# dict_keys(['H0', 'Omega_m', 'n_s', 'log_P_k_noisy'])

# %% [markdown]
# # (C) Flow Matching - Inference Networks

# %%
inference_network_flow = bf.networks.FlowMatching()

# %% [markdown]
# ### 4) Flow + CNN

# %%
workflow_flow_CNN = bf.BasicWorkflow(
     inference_network=inference_network_flow,
     summary_network=summary_network_CNN,
     adapter=adapter_std,
     simulator=simulator
)

# %%
history_flow_CNN = workflow_flow_CNN.fit_offline(
    data=training_data,
    epochs=200,
    num_batches_per_epoch=200,
    batch_size=128,
    validation_data = validation_data,
    #callbacks=[early_stop]
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - loss: 1181.0935 - val_loss: 4.4312
# Epoch 2/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 40.7919 - val_loss: 2.5127
# Epoch 3/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 4.4837 - val_loss: 1.3751
# Epoch 4/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4649 - val_loss: 1.0728
# Epoch 5/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1181 - val_loss: 1.1946
# Epoch 6/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0317 - val_loss: 0.8515
# Epoch 7/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0116 - val_loss: 1.1238
# Epoch 8/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.9785 - val_loss: 1.1804
# Epoch 9/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.9326 - val_loss: 1.1078
# Epoch 10/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.9527 - val_loss: 0.8387
# Epoch 11/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.9159 - val_loss: 0.7803
# Epoch 12/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.9020 - val_loss: 0.7537
# Epoch 13/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.8921 - val_loss: 0.7509
# Epoch 14/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.8042 - val_loss: 1.0930
# Epoch 15/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.8615 - val_loss: 0.8037
# Epoch 16/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.9127 - val_loss: 0.8713
# Epoch 17/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.8713 - val_loss: 0.9790
# Epoch 18/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7951 - val_loss: 0.7303
# Epoch 19/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7985 - val_loss: 0.8473
# Epoch 20/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7524 - val_loss: 0.7026
# Epoch 21/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7696 - val_loss: 0.6767
# Epoch 22/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7536 - val_loss: 0.7084
# Epoch 23/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7488 - val_loss: 0.7200
# Epoch 24/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7595 - val_loss: 0.6667
# Epoch 25/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7570 - val_loss: 0.6338
# Epoch 26/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.7292 - val_loss: 0.6604
# Epoch 27/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7270 - val_loss: 0.7004
# Epoch 28/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7308 - val_loss: 0.6924
# Epoch 29/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.7135 - val_loss: 0.6008
# Epoch 30/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7064 - val_loss: 0.6401
# Epoch 31/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7094 - val_loss: 0.6732
# Epoch 32/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.6999 - val_loss: 0.6247
# Epoch 33/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7101 - val_loss: 0.6313
# Epoch 34/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.6866 - val_loss: 0.7530
# Epoch 35/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7135 - val_loss: 0.9149
# Epoch 36/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7061 - val_loss: 0.6005
# Epoch 37/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6823 - val_loss: 0.8845
# Epoch 38/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6692 - val_loss: 0.6296
# Epoch 39/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6971 - val_loss: 0.5744
# Epoch 40/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6641 - val_loss: 0.7145
# Epoch 41/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6643 - val_loss: 0.5583
# Epoch 42/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7093 - val_loss: 0.6433
# Epoch 43/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6784 - val_loss: 0.6423
# Epoch 44/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.6437 - val_loss: 0.8050
# Epoch 45/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.6464 - val_loss: 0.5623
# Epoch 46/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.6185 - val_loss: 0.5745
# Epoch 47/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6311 - val_loss: 0.5804
# Epoch 48/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6153 - val_loss: 0.5488
# Epoch 49/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6008 - val_loss: 0.8200
# Epoch 50/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6028 - val_loss: 0.6430
# Epoch 51/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6023 - val_loss: 0.5372
# Epoch 52/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6012 - val_loss: 0.5708
# Epoch 53/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5702 - val_loss: 0.5342
# Epoch 54/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.5835 - val_loss: 0.5768
# Epoch 55/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.5774 - val_loss: 0.5460
# Epoch 56/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5708 - val_loss: 0.5045
# Epoch 57/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5512 - val_loss: 0.5958
# Epoch 58/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5690 - val_loss: 0.6014
# Epoch 59/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.5286 - val_loss: 0.5505
# Epoch 60/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5491 - val_loss: 0.4910
# Epoch 61/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.5475 - val_loss: 0.4856
# Epoch 62/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5524 - val_loss: 0.4538
# Epoch 63/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5090 - val_loss: 0.5492
# Epoch 64/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.5305 - val_loss: 0.4475
# Epoch 65/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5265 - val_loss: 0.6960
# Epoch 66/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5403 - val_loss: 0.5452
# Epoch 67/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5034 - val_loss: 0.5877
# Epoch 68/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5038 - val_loss: 0.5596
# Epoch 69/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4841 - val_loss: 0.4411
# Epoch 70/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4907 - val_loss: 0.4401
# Epoch 71/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5124 - val_loss: 0.5043
# Epoch 72/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4954 - val_loss: 0.4661
# Epoch 73/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4920 - val_loss: 0.4812
# Epoch 74/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4853 - val_loss: 0.4052
# Epoch 75/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4445 - val_loss: 0.3881
# Epoch 76/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4671 - val_loss: 0.3773
# Epoch 77/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4685 - val_loss: 0.4458
# Epoch 78/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4893 - val_loss: 0.4160
# Epoch 79/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4604 - val_loss: 0.4645
# Epoch 80/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4488 - val_loss: 0.4050
# Epoch 81/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4454 - val_loss: 0.6333
# Epoch 82/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4680 - val_loss: 0.4688
# Epoch 83/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4396 - val_loss: 0.4412
# Epoch 84/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4291 - val_loss: 0.5321
# Epoch 85/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4548 - val_loss: 0.4642
# Epoch 86/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4261 - val_loss: 0.4056
# Epoch 87/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4441 - val_loss: 0.4182
# Epoch 88/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4305 - val_loss: 0.3901
# Epoch 89/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4388 - val_loss: 0.4203
# Epoch 90/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4305 - val_loss: 0.3759
# Epoch 91/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4221 - val_loss: 0.4343
# Epoch 92/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4322 - val_loss: 0.3649
# Epoch 93/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4119 - val_loss: 0.3999
# Epoch 94/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4068 - val_loss: 0.4596
# Epoch 95/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4199 - val_loss: 0.4069
# Epoch 96/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4257 - val_loss: 0.3847
# Epoch 97/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4230 - val_loss: 0.4827
# Epoch 98/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4224 - val_loss: 0.4222
# Epoch 99/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4134 - val_loss: 0.4304
# Epoch 100/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4097 - val_loss: 0.4072
# Epoch 101/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.3920 - val_loss: 0.3946
# Epoch 102/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.3943 - val_loss: 0.4165
# Epoch 103/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.3797 - val_loss: 0.3941
# Epoch 104/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4105 - val_loss: 0.3911
# Epoch 105/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.4042 - val_loss: 0.4941
# Epoch 106/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3839 - val_loss: 0.3723
# Epoch 107/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.4018 - val_loss: 0.3974
# Epoch 108/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3787 - val_loss: 0.3429
# Epoch 109/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3897 - val_loss: 0.3749
# Epoch 110/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3857 - val_loss: 0.3915
# Epoch 111/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3814 - val_loss: 0.4108
# Epoch 112/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3776 - val_loss: 0.4045
# Epoch 113/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3832 - val_loss: 0.3208
# Epoch 114/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3898 - val_loss: 0.4498
# Epoch 115/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.3899 - val_loss: 0.3396
# Epoch 116/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.3859 - val_loss: 0.3785
# Epoch 117/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.3693 - val_loss: 0.4161
# Epoch 118/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.3763 - val_loss: 0.3742
# Epoch 119/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.3712 - val_loss: 0.3758
# Epoch 120/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3594 - val_loss: 0.4401
# Epoch 121/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3748 - val_loss: 0.3415
# Epoch 122/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3671 - val_loss: 0.3449
# Epoch 123/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3626 - val_loss: 0.2950
# Epoch 124/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3599 - val_loss: 0.3711
# Epoch 125/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3664 - val_loss: 0.3602
# Epoch 126/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3665 - val_loss: 0.3217
# Epoch 127/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3647 - val_loss: 0.3550
# Epoch 128/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3633 - val_loss: 0.3424
# Epoch 129/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3436 - val_loss: 0.3472
# Epoch 130/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3336 - val_loss: 0.3449
# Epoch 131/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3598 - val_loss: 0.3859
# Epoch 132/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3433 - val_loss: 0.3336
# Epoch 133/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3499 - val_loss: 0.3345
# Epoch 134/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3559 - val_loss: 0.3440
# Epoch 135/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3676 - val_loss: 0.3311
# Epoch 136/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3406 - val_loss: 0.3144
# Epoch 137/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3405 - val_loss: 0.3941
# Epoch 138/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3444 - val_loss: 0.3364
# Epoch 139/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3466 - val_loss: 0.3118
# Epoch 140/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3495 - val_loss: 0.3946
# Epoch 141/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3484 - val_loss: 0.3250
# Epoch 142/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3347 - val_loss: 0.3719
# Epoch 143/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3413 - val_loss: 0.3717
# Epoch 144/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3433 - val_loss: 0.3421
# Epoch 145/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3341 - val_loss: 0.3938
# Epoch 146/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3350 - val_loss: 0.3513
# Epoch 147/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3298 - val_loss: 0.3266
# Epoch 148/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3330 - val_loss: 0.3624
# Epoch 149/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3259 - val_loss: 0.3388
# Epoch 150/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3181 - val_loss: 0.3392
# Epoch 151/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3397 - val_loss: 0.2996
# Epoch 152/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3355 - val_loss: 0.3529
# Epoch 153/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3338 - val_loss: 0.3298
# Epoch 154/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3304 - val_loss: 0.3279
# Epoch 155/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3256 - val_loss: 0.3190
# Epoch 156/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3300 - val_loss: 0.3178
# Epoch 157/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3210 - val_loss: 0.3613
# Epoch 158/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3264 - val_loss: 0.3220
# Epoch 159/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3220 - val_loss: 0.3136
# Epoch 160/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3195 - val_loss: 0.3606
# Epoch 161/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3249 - val_loss: 0.4012
# Epoch 162/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3158 - val_loss: 0.3626
# Epoch 163/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3175 - val_loss: 0.3018
# Epoch 164/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3181 - val_loss: 0.3193
# Epoch 165/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3169 - val_loss: 0.3366
# Epoch 166/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3154 - val_loss: 0.3629
# Epoch 167/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3134 - val_loss: 0.3198
# Epoch 168/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3199 - val_loss: 0.3234
# Epoch 169/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3162 - val_loss: 0.3234
# Epoch 170/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3153 - val_loss: 0.3601
# Epoch 171/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3163 - val_loss: 0.3035
# Epoch 172/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3101 - val_loss: 0.3333
# Epoch 173/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3120 - val_loss: 0.2970
# Epoch 174/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3163 - val_loss: 0.3079
# Epoch 175/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3208 - val_loss: 0.3175
# Epoch 176/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3125 - val_loss: 0.3446
# Epoch 177/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3109 - val_loss: 0.3232
# Epoch 178/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3101 - val_loss: 0.3065
# Epoch 179/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3078 - val_loss: 0.3400
# Epoch 180/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3076 - val_loss: 0.3328
# Epoch 181/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3152 - val_loss: 0.3460
# Epoch 182/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3047 - val_loss: 0.2906
# Epoch 183/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3035 - val_loss: 0.3240
# Epoch 184/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3073 - val_loss: 0.3144
# Epoch 185/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3033 - val_loss: 0.3112
# Epoch 186/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3078 - val_loss: 0.3360
# Epoch 187/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3060 - val_loss: 0.3310
# Epoch 188/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.3153 - val_loss: 0.3157
# Epoch 189/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.3009 - val_loss: 0.3107
# Epoch 190/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.3078 - val_loss: 0.3510
# Epoch 191/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.3032 - val_loss: 0.3107
# Epoch 192/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3044 - val_loss: 0.3178
# Epoch 193/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.3061 - val_loss: 0.3265
# Epoch 194/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3113 - val_loss: 0.3412
# Epoch 195/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3089 - val_loss: 0.3057
# Epoch 196/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3132 - val_loss: 0.3186
# Epoch 197/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3018 - val_loss: 0.3204
# Epoch 198/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3089 - val_loss: 0.3247
# Epoch 199/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3020 - val_loss: 0.3362
# Epoch 200/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3070 - val_loss: 0.3027

# %%
figures_flow_CNN = workflow_flow_CNN.plot_default_diagnostics(
    test_data=test_data,
    rank_histogram_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}  
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25424\2119365998.py in ?()
# ----> 1 figures_flow_CNN = workflow_flow_CNN.plot_default_diagnostics(
#       2     test_data=test_data,
#       3     rank_histogram_kwargs={"figsize": (15, 3), "label_fontsize": 12},
#       4     recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py in ?(self, test_data, num_samples, variable_keys, variable_names, **kwargs)
#     389             A dictionary where keys correspond to different diagnostic plot
#     390             types, and values are the respective matplotlib Figure objects.
#     391         """
#     392
# --> 393         samples, test_data = self._prepare_for_diagnostics(test_data, num_samples, **kwargs)
#     394
#     395         figures = dict()
#     396
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\workflows\basic_workflow.py in ?(self, test_data, num_samples, **kwargs)
#     965             test_data = self.simulator.sample(test_data, **kwargs.pop("test_data_kwargs", {}))
#     966         elif isinstance(test_data, int):
#     967             raise ValueError(f"No simulator found for generating {test_data} data sets.")
#     968
# --> 969         samples = self.approximator.sample(
#     970             num_samples=num_samples, conditions=test_data, **kwargs.get("approximator_kwargs", {})
#     971         )
#     972
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\continuous_approximator.py in ?(self, num_samples, conditions, split, **kwargs)
#     451         # Remove any superfluous keys, just retain actual conditions
#     452         conditions = {k: v for k, v in conditions.items() if k in self.CONDITION_KEYS}
#     453
#     454         # Sample and undo optional standardization
# --> 455         samples = self._sample(num_samples=num_samples, **conditions, **kwargs)
#     456
#     457         if "inference_variables" in self.standardize:
#     458             samples = self.standardize_layers["inference_variables"](samples, forward=False)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\approximators\continuous_approximator.py in ?(self, num_samples, inference_conditions, summary_variables, **kwargs)
#     539             batch_shape = keras.ops.shape(inference_conditions)[:-1]
#     540         else:
#     541             batch_shape = keras.ops.shape(inference_conditions)[1:-1]
#     542
# --> 543         return self.inference_network.sample(
#     544             batch_shape, conditions=inference_conditions, **filter_kwargs(kwargs, self.inference_network.sample)
#     545         )
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\decorators.py in ?(*args, **kwargs)
#      59             # check if multiple aliases are specified
#      60             matches = [name for name in kwargs if name in aliases]
#      61
#      62             if not matches:
# ---> 63                 return fn(*args, **kwargs)
#      64
#      65             if len(matches) > 1 or (len(matches) > 0 and len(args) > argpos):
#      66                 raise TypeError(
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\decorators.py in ?(*args, **kwargs)
#      91             elif len(args) > argpos:
#      92                 args = list(args)
#      93                 args[argpos] = callback(args[argpos])
#      94
# ---> 95             return fn(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\inference_network.py in ?(self, batch_shape, conditions, **kwargs)
#      47     @allow_batch_size
#      48     def sample(self, batch_shape: Shape, conditions: Tensor = None, **kwargs) -> Tensor:
#      49         samples = self.base_distribution.sample(batch_shape)
# ---> 50         samples = self(samples, conditions=conditions, inverse=True, density=False, **kwargs)
#      51         return samples
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\inference_network.py in ?(self, xz, conditions, inverse, density, training, **kwargs)
#      30         training: bool = False,
#      31         **kwargs,
#      32     ) -> Tensor | tuple[Tensor, Tensor]:
#      33         if inverse:
# ---> 34             return self._inverse(xz, conditions=conditions, density=density, training=training, **kwargs)
#      35         return self._forward(xz, conditions=conditions, density=density, training=training, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\flow_matching\flow_matching.py in ?(self, z, conditions, density, training, **kwargs)
#     221         def deltas(time, xz):
#     222             return {"xz": self.velocity(xz, time=time, conditions=conditions, training=training)}
#     223
#     224         state = {"xz": z}
# --> 225         state = integrate(deltas, state, start_time=0.0, stop_time=1.0, **(self.integrate_kwargs | kwargs))
#     226
#     227         x = state["xz"]
#     228
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\integrate.py in ?(fn, state, start_time, stop_time, min_steps, max_steps, steps, method, **kwargs)
#     288             raise ValueError(
#     289                 "Please provide start_time and stop_time for the integration, was "
#     290                 f"'start_time={start_time}', 'stop_time={stop_time}'."
#     291             )
# --> 292         return integrate_fixed(fn, state, start_time, stop_time, steps, method, **kwargs)
#     293     elif isinstance(steps, Sequence) or isinstance(steps, np.ndarray) or keras.ops.is_tensor(steps):
#     294         return integrate_scheduled(fn, state, steps, method, **kwargs)
#     295     else:
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\integrate.py in ?(fn, state, start_time, stop_time, steps, method, **kwargs)
#     154         _state, _time, _ = step_fn(_state, _time, step_size)
#     155
#     156         return _state, _time
#     157
# --> 158     state, time = keras.ops.fori_loop(0, steps, body, (state, time))
#     159
#     160     return state
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\core.py in ?(lower, upper, body_fun, init_val)
#     693     45
#     694     """
#     695     if any_symbolic_tensors((lower, upper, init_val)):
#     696         return ForiLoop(lower, upper, body_fun).symbolic_call(init_val)
# --> 697     return backend.core.fori_loop(lower, upper, body_fun, init_val)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py in ?(lower, upper, body_fun, init_val)
#     631 def fori_loop(lower, upper, body_fun, init_val):
# --> 632     return tf.while_loop(
#     633         lambda i, val: i < upper,
#     634         lambda i, val: (i + 1, body_fun(i, val)),
#     635         (lower, init_val),
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     237   ...   print(sess.run(x_out).shape)
#     238   (1000, 100)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py in ?(i, val)
# --> 634         lambda i, val: (i + 1, body_fun(i, val)),
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\integrate.py in ?(_loop_var, _loop_state)
#     152     def body(_loop_var, _loop_state):
#     153         _state, _time = _loop_state
# --> 154         _state, _time, _ = step_fn(_state, _time, step_size)
#     155
#     156         return _state, _time
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\utils\integrate.py in ?(fn, state, time, step_size, tolerance, min_step_size, max_step_size, use_adaptive_step_size)
#      23     min_step_size: ArrayLike = -float("inf"),
#      24     max_step_size: ArrayLike = float("inf"),
#      25     use_adaptive_step_size: bool = False,
#      26 ) -> (dict[str, ArrayLike], ArrayLike, ArrayLike):
# ---> 27     k1 = fn(time, **filter_kwargs(state, fn))
#      28
#      29     if use_adaptive_step_size:
#      30         intermediate_state = state.copy()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\flow_matching\flow_matching.py in ?(time, xz)
#     221         def deltas(time, xz):
# --> 222             return {"xz": self.velocity(xz, time=time, conditions=conditions, training=training)}
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\flow_matching\flow_matching.py in ?(self, xz, time, conditions, training)
#     161             xtc = keras.ops.concatenate([xz, time], axis=-1)
#     162         else:
#     163             xtc = keras.ops.concatenate([xz, time, conditions], axis=-1)
#     164
# --> 165         return self.output_projector(self.subnet(xtc, training=training), training=training)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\sequential\sequential.py in ?(self, inputs, training, mask)
#      50     def call(self, inputs, training=None, mask=None):
#      51         x = inputs
#      52         for layer in self._layers:
#      53             kwargs = self._make_kwargs_for_layer(layer, training, mask)
# ---> 54             x = layer(x, **kwargs)
#      55         return x
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\residual\residual.py in ?(self, x, training, mask)
#      52     def call(self, x: Tensor, training: bool = None, mask: bool = None) -> Tensor:
# ---> 53         return self.projector(x) + super().call(x, training=training, mask=mask)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bayesflow\networks\sequential\sequential.py in ?(self, inputs, training, mask)
#      50     def call(self, inputs, training=None, mask=None):
#      51         x = inputs
#      52         for layer in self._layers:
#      53             kwargs = self._make_kwargs_for_layer(layer, training, mask)
# ---> 54             x = layer(x, **kwargs)
#      55         return x
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\activation.py in ?(self, inputs)
#      32     def call(self, inputs):
# ---> 33         return self.activation(inputs)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\activations\activations.py in ?(x)
#     640
#     641     - [Misra, 2019](https://arxiv.org/abs/1908.08681)
#     642     """
#     643     x = backend.convert_to_tensor(x)
# --> 644     return Mish.static_call(x)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\activations\activations.py in ?(x)
#     619     @staticmethod
#     620     def static_call(x):
# --> 621         return x * backend.nn.tanh(backend.nn.softplus(x))
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\nn.py in ?(x)
#      46 def softplus(x):
# ---> 47     return tf.math.softplus(x)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\math_ops.py in ?(features, name)
#     653     name: Optional: name to associate with this operation.
#     654   Returns:
#     655     `Tensor`
#     656   """
# --> 657   return gen_nn_ops.softplus(features, name)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(features, name)
#   12129         _ctx, "Softplus", name, features)
#   12130       return _result
#   12131     except _core._NotOkStatusException as e:
#   12132       _ops.raise_from_not_ok_status(e, name)
# > 12133     except _core._FallbackException:
#   12134       pass
#   12135     try:
#   12136       return softplus_eager_fallback(
#
# KeyboardInterrupt:
